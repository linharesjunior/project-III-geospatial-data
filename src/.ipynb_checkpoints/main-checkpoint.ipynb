# %%
import requests
from pymongo import MongoClient
from pymongo import GEOSPHERE
import pandas as pd
import json
import os
import geopandas as gpd
from cartoframes.viz import Map, Layer, popup_element
from getpass import getpass
import time
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd
from collections import defaultdict
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %% [markdown]
# ### MongoDB query ###

# %%
client = MongoClient("localhost:27017")
db = client.get_database("ironhack")
companies = db.get_collection("companies")

# %%
query = {"category_code": "games_video", "number_of_employees": {"$gte": 100, "$lte": 300}, "offices.country_code": {"$exists": True}, "offices.latitude": {"$exists": True}, "offices.latitude": {"$exists": True}}
projection = {"_id":0, "name":1, "category_code": 1, "offices.latitude": 1, "offices.longitude": 1, "number_of_employees": 1}
results = list(companies.find(query, projection))
results [:5]
# Out:
# [{'name': 'Livestream',
#   'category_code': 'games_video',
#   'number_of_employees': 120,
#   'offices': [{'latitude': 40.726155, 'longitude': -73.995625}]},
#  {'name': 'Ustream',
#   'category_code': 'games_video',
#   'number_of_employees': 250,
#   'offices': [{'latitude': 37.392936, 'longitude': -122.07948},
#    {'latitude': None, 'longitude': None},
#    {'latitude': None, 'longitude': None}]},
#  {'name': 'RockYou',
#   'category_code': 'games_video',
#   'number_of_employees': 106,
#   'offices': [{'latitude': 37.484619, 'longitude': -122.206893}]},
#  {'name': 'hi5',
#   'category_code': 'games_video',
#   'number_of_employees': 100,
#   'offices': [{'latitude': 37.788668, 'longitude': -122.400558}]},
#  {'name': 'Zango',
#   'category_code': 'games_video',
#   'number_of_employees': 225,
#   'offices': [{'latitude': 47.579208, 'longitude': -122.155668}]}]

# %%
# checking how many game companies, with the number of employes from 100 to 300, per country

query = {"category_code": "games_video", "number_of_employees": {"$gte": 100, "$lte": 300}, "offices.country_code": {"$exists": True}, "offices.latitude": {"$exists": True}, "offices.latitude": {"$exists": True}}
projection = {"_id": 0, "offices.country_code": 1}

results = list(companies.find(query, projection))
country_count = defaultdict(int)

for result in results:
    country_code = result.get("offices", [{}])[0].get("country_code", "Unknown")
    country_count[country_code] += 1

for country, count in country_count.items():
    print(f"{country} - {count}")
# Out:
# USA - 21
# SGP - 1
# GBR - 2
# IND - 2
# ITA - 1
# NLD - 1
# CHE - 1
# DEU - 1
# SWE - 1
# FRA - 1
# UKR - 1

# %%
# As USA is the country with more game companies, checkong now the cities

query = {
    "category_code": "games_video",
    "number_of_employees": {"$gte": 100, "$lte": 300},
    "offices.country_code": "USA",
    "offices.city": {"$exists": True},
    "offices.latitude": {"$exists": True},
    "offices.longitude": {"$exists": True}
}

projection = {
    "_id": 0,
    "offices.city": 1
}

results = list(companies.find(query, projection))
us_city_count = defaultdict(int)

for result in results:
    city = result.get("offices", [{}])[0].get("city", "Unknown")
    us_city_count[city] += 1

print("City, Count")
for city, count in us_city_count.items():
    print(f"{city} - {count}")
# Out:
# City, Count
# New York - 3
# San Francisco - 7
# Redwood City - 1
# Bellevue - 1
# Los Angeles - 3
# Dundee - 1
# Westwood - 1
# Brooklyn - 1
# Torino - 1
# Sunnyvale - 3
# Seattle - 1
# Oxford - 1
# Kharkov - 1

# %%
# looking for game companies, with number of employees Between 100 and 300

my_map = folium.Map(location=[40.726155, -121.997355], zoom_start=3)

for index, row in df.iterrows():
    if row['category_code'] == 'games_video':
        marker_color = 'red'
        marker_size = 'large'

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['name'],
        icon=folium.Icon(color=marker_color, icon_color='white', icon=marker_size)
    ).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0a82af41c7e6bc24cd0e8a612ed9487 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0a82af41c7e6bc24cd0e8a612ed9487&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0a82af41c7e6bc24cd0e8a612ed9487 = L.map(
#                 &quot;map_f0a82af41c7e6bc24cd0e8a612ed9487&quot;,
#                 {
#                     center: [40.726155, -121.997355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b638d98172361ea573ef81c5c22a47b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0a82af41c7e6bc24cd0e8a612ed9487);
#
#
#             var marker_992f55e7170f7e70e17e3e0be9e75b55 = L.marker(
#                 [40.726155, -73.995625],
#                 {}
#             ).addTo(map_f0a82af41c7e6bc24cd0e8a612ed9487);
#
#
#             var icon_5ddf40ae2a229352af347a7c16172eed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;large&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_992f55e7170f7e70e17e3e0be9e75b55.setIcon(icon_5ddf40ae2a229352af347a7c16172eed);
#
#
#         var popup_0b657cc81fdda693ae5d25e0b0729d87 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac6aad31ec7f93b529e74b50e03f3c3a = $(`&lt;div id=&quot;html_ac6aad31ec7f93b529e74b50e03f3c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livestream&lt;/div&gt;`)[0];
#                 popup_0b657cc81fdda693ae5d25e0b0729d87.setContent(html_ac6aad31ec7f93b529e74b50e03f3c3a);
#
#
#
#         marker_992f55e7170f7e70e17e3e0be9e75b55.bindPopup(popup_0b657cc81fdda693ae5d25e0b0729d87)
#         ;
#
#
#
#
#             var marker_d229de8aafcd3ead5a178f3041a5ad3f = L.marker(
#                 [37.392936, -122.07948],
#                 {}
#             ).addTo(map_f0a82af41c7e6bc24cd0e8a612ed9487);
#
#
#             var icon_806412716c7b00e8ee2cd5addac6d7cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;large&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d229de8aafcd3ead5a178f3041a5ad3f.setIcon(icon_806412716c7b00e8ee2cd5addac6d7cc);
#
#
#         var popup_7304ae87f4af91541211a551d6abb24f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa26673e52e20869bd64c2af30801c8f = $(`&lt;div id=&quot;html_fa26673e52e20869bd64c2af30801c8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ustream&lt;/div&gt;`)[0];
#                 popup_7304ae87f4af91541211a551d6abb24f.setContent(html_fa26673e52e20869bd64c2af30801c8f);
#
#
#
#         marker_d229de8aafcd3ead5a178f3041a5ad3f.bindPopup(popup_7304ae87f4af91541211a551d6abb24f)
#         ;
#
#
#
#
#             var marker_5c04896babc0a879a7616ced692c1611 = L.marker(
#                 [37.484619, -122.206893],
#                 {}
#             ).addTo(map_f0a82af41c7e6bc24cd0e8a612ed9487);
#
#
#             var icon_8acb678a668523a0fa9009f2914c594b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;large&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5c04896babc0a879a7616ced692c1611.setIcon(icon_8acb678a668523a0fa9009f2914c594b);
#
#
#         var popup_e3cb659304305849896935c4095c2de3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd51c29764bced0d5e4389c05f0446c5 = $(`&lt;div id=&quot;html_bd51c29764bced0d5e4389c05f0446c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RockYou&lt;/div&gt;`)[0];
#                 popup_e3cb659304305849896935c4095c2de3.setContent(html_bd51c29764bced0d5e4389c05f0446c5);
#
#
#
#         marker_5c04896babc0a879a7616ced692c1611.bindPopup(popup_e3cb659304305849896935c4095c2de3)
#         ;
#
#
#
#
#             var marker_713e18388a70399b8b4da7939587402a = L.marker(
#                 [37.788668, -122.400558],
#                 {}
#             ).addTo(map_f0a82af41c7e6bc24cd0e8a612ed9487);
#
#
#             var icon_fe0d61b5dca1db20cd97251ca1f51a81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;large&quot;, &quot;iconCo

# %%
query = {"category_code": "games_video", "number_of_employees": {"$gte": 100, "$lte": 300}, "offices.country_code": {"$exists": True}, "offices.latitude": {"$exists": True}, "offices.latitude": {"$exists": True}}
projection = {"_id":0, "name":1, "category_code": 1, "offices.latitude": 1, "offices.longitude": 1, "number_of_employees": 1}
results2 = list(companies.find(query, projection))
results2 [:5]
# Out:
# [{'name': 'Livestream',
#   'category_code': 'games_video',
#   'number_of_employees': 120,
#   'offices': [{'latitude': 40.726155, 'longitude': -73.995625}]},
#  {'name': 'Ustream',
#   'category_code': 'games_video',
#   'number_of_employees': 250,
#   'offices': [{'latitude': 37.392936, 'longitude': -122.07948},
#    {'latitude': None, 'longitude': None},
#    {'latitude': None, 'longitude': None}]},
#  {'name': 'RockYou',
#   'category_code': 'games_video',
#   'number_of_employees': 106,
#   'offices': [{'latitude': 37.484619, 'longitude': -122.206893}]},
#  {'name': 'hi5',
#   'category_code': 'games_video',
#   'number_of_employees': 100,
#   'offices': [{'latitude': 37.788668, 'longitude': -122.400558}]},
#  {'name': 'Zango',
#   'category_code': 'games_video',
#   'number_of_employees': 225,
#   'offices': [{'latitude': 47.579208, 'longitude': -122.155668}]}]

# %%
df = pd.DataFrame(results2)
df
# Out:
#                      name category_code  number_of_employees  \
# 0              Livestream   games_video                  120
# 1                 Ustream   games_video                  250
# 2                 RockYou   games_video                  106
# 3                     hi5   games_video                  100
# 4                   Zango   games_video                  225
# 5                    hulu   games_video                  153
# 6                   mig33   games_video                  100
# 7                   Zynga   games_video                  115
# 8               GameDuell   games_video                  200
# 9   Social Gaming Network   games_video                  100
# 10                 Boonty   games_video                  150
# 11        Realtime Worlds   games_video                  225
# 12            Modern Feed   games_video                  123
# 13                Turbine   games_video                  200
# 14                   iWin   games_video                  103
# 15                 VBS TV   games_video                  100
# 16                 ngmoco   games_video                  150
# 17          Whereismyboss   games_video                  100
# 18               deltatre   games_video                  225
# 19             Indiagames   games_video                  300
# 20             SPIL GAMES   games_video                  300
# 21               Miniclip   games_video                  140
# 22           RGB Networks   games_video                  125
# 23            i-Jet Media   games_video                  150
# 24   Turtle Entertainment   games_video                  175
# 25     Unity Technologies   games_video                  200
# 26                 Z2Live   games_video                  130
# 27              ZillionTV   games_video                  100
# 28          NaturalMotion   games_video                  150
# 29                 Aspiro   games_video                  115
# 30              2 Minutes   games_video                  105
# 31                  Exent   games_video                  100
# 32       G5 Entertainment   games_video                  107
#
#                                               offices
# 0   [{'latitude': 40.726155, 'longitude': -73.9956...
# 1   [{'latitude': 37.392936, 'longitude': -122.079...
# 2   [{'latitude': 37.484619, 'longitude': -122.206...
# 3   [{'latitude': 37.788668, 'longitude': -122.400...
# 4   [{'latitude': 47.579208, 'longitude': -122.155...
# 5   [{'latitude': 34.031276, 'longitude': -118.456...
# 6   [{'latitude': 37.580304, 'longitude': -122.343...
# 7   [{'latitude': 37.765158, 'longitude': -122.404...
# 8   [{'latitude': None, 'longitude': None}, {'lati...
# 9   [{'latitude': 37.446823, 'longitude': -122.161...
# 10  [{'latitude': 40.717248, 'longitude': -74.0026...
# 11  [{'latitude': 56.461428, 'longitude': -2.96811...
# 12  [{'latitude': 34.085749, 'longitude': -118.343...
# 13  [{'latitude': 42.214483, 'longitude': -71.1859...
# 14  [{'latitude': 37.781689, 'longitude': -122.391...
# 15  [{'latitude': 40.720764, 'longitude': -73.9579...
# 16  [{'latitude': 37.7705096, 'longitude': -122.40...
# 17            [{'latitude': None, 'longitude': None}]
# 18  [{'latitude': 45.058576, 'longitude': 7.649614...
# 19            [{'latitude': None, 'longitude': None}]
# 20  [{'latitude': 52.220726, 'longitude': 5.198824...
# 21            [{'latitude': None, 'longitude': None}]
# 22  [{'latitude': 37.4123706, 'longitude': -122.02...
# 23  [{'latitude': 37.384239, 'longitude': -122.012...
# 24  [{'latitude': 50.9272941, 'longitude': 6.97649...
# 25  [{'latitude': 55.6924605, 'longitude': 12.5301...
# 26  [{'latitude': 47.6103008, 'longitude': -122.33...
# 27  [{'latitude': 37.3738725, 'longitude': -121.99...
# 28  [{'latitude': None, 'longitude': None}, {'lati...
# 29            [{'latitude': None, 'longitude': None}]
# 30  [{'latitude': 48.8502056, 'longitude': 2.36980...
# 31  [{'latitude': 40.7523796, 'longitude': -74.005...
# 32  [{'latitude': None, 'longitude': None}, {'lati...

# %%
df['latitude'] = df['offices'].apply(lambda x: x[0]['latitude'])
df['longitude'] = df['offices'].apply(lambda x: x[0]['longitude'])
df
# Out:
#                      name category_code  number_of_employees  \
# 0              Livestream   games_video                  120
# 1                 Ustream   games_video                  250
# 2                 RockYou   games_video                  106
# 3                     hi5   games_video                  100
# 4                   Zango   games_video                  225
# 5                    hulu   games_video                  153
# 6                   mig33   games_video                  100
# 7                   Zynga   games_video                  115
# 8               GameDuell   games_video                  200
# 9   Social Gaming Network   games_video                  100
# 10                 Boonty   games_video                  150
# 11        Realtime Worlds   games_video                  225
# 12            Modern Feed   games_video                  123
# 13                Turbine   games_video                  200
# 14                   iWin   games_video                  103
# 15                 VBS TV   games_video                  100
# 16                 ngmoco   games_video                  150
# 17          Whereismyboss   games_video                  100
# 18               deltatre   games_video                  225
# 19             Indiagames   games_video                  300
# 20             SPIL GAMES   games_video                  300
# 21               Miniclip   games_video                  140
# 22           RGB Networks   games_video                  125
# 23            i-Jet Media   games_video                  150
# 24   Turtle Entertainment   games_video                  175
# 25     Unity Technologies   games_video                  200
# 26                 Z2Live   games_video                  130
# 27              ZillionTV   games_video                  100
# 28          NaturalMotion   games_video                  150
# 29                 Aspiro   games_video                  115
# 30              2 Minutes   games_video                  105
# 31                  Exent   games_video                  100
# 32       G5 Entertainment   games_video                  107
#
#                                               offices   latitude   longitude
# 0   [{'latitude': 40.726155, 'longitude': -73.9956...  40.726155  -73.995625
# 1   [{'latitude': 37.392936, 'longitude': -122.079...  37.392936 -122.079480
# 2   [{'latitude': 37.484619, 'longitude': -122.206...  37.484619 -122.206893
# 3   [{'latitude': 37.788668, 'longitude': -122.400...  37.788668 -122.400558
# 4   [{'latitude': 47.579208, 'longitude': -122.155...  47.579208 -122.155668
# 5   [{'latitude': 34.031276, 'longitude': -118.456...  34.031276 -118.456806
# 6   [{'latitude': 37.580304, 'longitude': -122.343...  37.580304 -122.343679
# 7   [{'latitude': 37.765158, 'longitude': -122.404...  37.765158 -122.404234
# 8   [{'latitude': None, 'longitude': None}, {'lati...        NaN         NaN
# 9   [{'latitude': 37.446823, 'longitude': -122.161...  37.446823 -122.161523
# 10  [{'latitude': 40.717248, 'longitude': -74.0026...  40.717248  -74.002662
# 11  [{'latitude': 56.461428, 'longitude': -2.96811...  56.461428   -2.968111
# 12  [{'latitude': 34.085749, 'longitude': -118.343...  34.085749 -118.343791
# 13  [{'latitude': 42.214483, 'longitude': -71.1859...  42.214483  -71.185964
# 14  [{'latitude': 37.781689, 'longitude': -122.391...  37.781689 -122.391061
# 15  [{'latitude': 40.720764, 'longitude': -73.9579...  40.720764  -73.957968
# 16  [{'latitude': 37.7705096, 'longitude': -122.40...  37.770510 -122.401581
# 17            [{'latitude': None, 'longitude': None}]        NaN         NaN
# 18  [{'latitude': 45.058576, 'longitude': 7.649614...  45.058576    7.649614
# 19            [{'latitude': None, 'longitude': None}]        NaN         NaN
# 20  [{'latitude': 52.220726, 'longitude': 5.198824...  52.220726    5.198824
# 21            [{'latitude': None, 'longitude': None}]        NaN         NaN
# 22  [{'latitude': 37.4123706, 'longitude': -122.02...  37.412371 -122.021627
# 23  [{'latitude': 37.384239, 'longitude': -122.012...  37.384239 -122.012475
# 24  [{'latitude': 50.9272941, 'longitude': 6.97649...  50.927294    6.976498
# 25  [{'latitude': 55.6924605, 'longitude': 12.5301...  55.692461   12.530107
# 26  [{'latitude': 47.6103008, 'longitude': -122.33...  47.610301 -122.339978
# 27  [{'latitude': 37.3738725, 'longitude': -121.99...  37.373872 -121.997355
# 28  [{'latitude': None, 'longitude': None}, {'lati...        NaN         NaN
# 29            [{'latitude': None, 'longitude': None}]        NaN         NaN
# 30  [{'latitude': 48.8502056, 'longitude': 2.36980...  48.850206    2.369803
# 31  [{'latitude': 40.7523796, 'longitude': -74.005...  40.752380  -74.005568
# 32  [{'latitude': None, 'longitude': None}, {'lati...        NaN         NaN

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                      name category_code  number_of_employees  \
# 0              Livestream   games_video                  120
# 1                 Ustream   games_video                  250
# 2                 RockYou   games_video                  106
# 3                     hi5   games_video                  100
# 4                   Zango   games_video                  225
# 5                    hulu   games_video                  153
# 6                   mig33   games_video                  100
# 7                   Zynga   games_video                  115
# 8   Social Gaming Network   games_video                  100
# 9                  Boonty   games_video                  150
# 10        Realtime Worlds   games_video                  225
# 11            Modern Feed   games_video                  123
# 12                Turbine   games_video                  200
# 13                   iWin   games_video                  103
# 14                 VBS TV   games_video                  100
# 15                 ngmoco   games_video                  150
# 16               deltatre   games_video                  225
# 17             SPIL GAMES   games_video                  300
# 18           RGB Networks   games_video                  125
# 19            i-Jet Media   games_video                  150
# 20   Turtle Entertainment   games_video                  175
# 21     Unity Technologies   games_video                  200
# 22                 Z2Live   games_video                  130
# 23              ZillionTV   games_video                  100
# 24              2 Minutes   games_video                  105
# 25                  Exent   games_video                  100
#
#                                               offices   latitude   longitude
# 0   [{'latitude': 40.726155, 'longitude': -73.9956...  40.726155  -73.995625
# 1   [{'latitude': 37.392936, 'longitude': -122.079...  37.392936 -122.079480
# 2   [{'latitude': 37.484619, 'longitude': -122.206...  37.484619 -122.206893
# 3   [{'latitude': 37.788668, 'longitude': -122.400...  37.788668 -122.400558
# 4   [{'latitude': 47.579208, 'longitude': -122.155...  47.579208 -122.155668
# 5   [{'latitude': 34.031276, 'longitude': -118.456...  34.031276 -118.456806
# 6   [{'latitude': 37.580304, 'longitude': -122.343...  37.580304 -122.343679
# 7   [{'latitude': 37.765158, 'longitude': -122.404...  37.765158 -122.404234
# 8   [{'latitude': 37.446823, 'longitude': -122.161...  37.446823 -122.161523
# 9   [{'latitude': 40.717248, 'longitude': -74.0026...  40.717248  -74.002662
# 10  [{'latitude': 56.461428, 'longitude': -2.96811...  56.461428   -2.968111
# 11  [{'latitude': 34.085749, 'longitude': -118.343...  34.085749 -118.343791
# 12  [{'latitude': 42.214483, 'longitude': -71.1859...  42.214483  -71.185964
# 13  [{'latitude': 37.781689, 'longitude': -122.391...  37.781689 -122.391061
# 14  [{'latitude': 40.720764, 'longitude': -73.9579...  40.720764  -73.957968
# 15  [{'latitude': 37.7705096, 'longitude': -122.40...  37.770510 -122.401581
# 16  [{'latitude': 45.058576, 'longitude': 7.649614...  45.058576    7.649614
# 17  [{'latitude': 52.220726, 'longitude': 5.198824...  52.220726    5.198824
# 18  [{'latitude': 37.4123706, 'longitude': -122.02...  37.412371 -122.021627
# 19  [{'latitude': 37.384239, 'longitude': -122.012...  37.384239 -122.012475
# 20  [{'latitude': 50.9272941, 'longitude': 6.97649...  50.927294    6.976498
# 21  [{'latitude': 55.6924605, 'longitude': 12.5301...  55.692461   12.530107
# 22  [{'latitude': 47.6103008, 'longitude': -122.33...  47.610301 -122.339978
# 23  [{'latitude': 37.3738725, 'longitude': -121.99...  37.373872 -121.997355
# 24  [{'latitude': 48.8502056, 'longitude': 2.36980...  48.850206    2.369803
# 25  [{'latitude': 40.7523796, 'longitude': -74.005...  40.752380  -74.005568

# %%
token = getpass()
# Out:
# ········

# %%
client_id = getpass()
# Out:
# ········

# %%
client_secret = getpass()

# %% [markdown]
# ### Getting nearby venues through Foursquare for San Fracisco ###

# %%
where = "San Francisco, USA"

# %%
lat = 37.765158
lon = -122.404234

# %%
# locating a random company in San Francisco from the game and number of employees criteria

latitude = 37.765158
longitude = -122.404234

m = folium.Map(location=[latitude, longitude], zoom_start=12)
folium.Marker([latitude, longitude], popup="Your Location").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa2d1d651cf77280cd4d91c7e24abfdb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa2d1d651cf77280cd4d91c7e24abfdb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa2d1d651cf77280cd4d91c7e24abfdb = L.map(
#                 &quot;map_aa2d1d651cf77280cd4d91c7e24abfdb&quot;,
#                 {
#                     center: [37.765158, -122.404234],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82072173c53470bb97e3d044bc6750fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa2d1d651cf77280cd4d91c7e24abfdb);
#
#
#             var marker_ea87ea902c9936d0e6eb6593b8bad4a9 = L.marker(
#                 [37.765158, -122.404234],
#                 {}
#             ).addTo(map_aa2d1d651cf77280cd4d91c7e24abfdb);
#
#
#         var popup_90a1d1c0a328a6d38449b0265bce002c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5caec80f24ee48b517c3bc077f3e985a = $(`&lt;div id=&quot;html_5caec80f24ee48b517c3bc077f3e985a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Your Location&lt;/div&gt;`)[0];
#                 popup_90a1d1c0a328a6d38449b0265bce002c.setContent(html_5caec80f24ee48b517c3bc077f3e985a);
#
#
#
#         marker_ea87ea902c9936d0e6eb6593b8bad4a9.bindPopup(popup_90a1d1c0a328a6d38449b0265bce002c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# checking for close Child School

def requests_for_foursquare (query, lat, lon, radius=2000, limit=1):
    lat = 37.765158
    lon = -122.404234 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
child_school = requests_for_foursquare ("Preschool", lat, lon, radius=2000, limit=5)
child_school
# Out:
# {'results': [{'fsq_id': '5dbb78957e097c00089cb7c9',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1229,
#    'geocodes': {'main': {'latitude': 37.761362, 'longitude': -122.41741},
#     'roof': {'latitude': 37.761362, 'longitude': -122.41741}},
#    'link': '/v3/places/5dbb78957e097c00089cb7c9',
#    'location': {'address': '722 S Van Ness Ave',
#     'census_block': '060750208022000',
#     'country': 'US',
#     'cross_street': '18th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '722 S Van Ness Ave (18th St), San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'Petite Explorer Preschool',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '5ab5e7c3237dee25adca69c7',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 1313,
#    'geocodes': {'drop_off': {'latitude': 37.776865, 'longitude': -122.405214},
#     'main': {'latitude': 37.777038, 'longitude': -122.405075},
#     'roof': {'latitude': 37.777038, 'longitude': -122.405075}},
#    'link': '/v3/places/5ab5e7c3237dee25adca69c7',
#    'location': {'address': '85 Columbia Sq',
#     'census_block': '060750178043001',
#     'country': 'US',
#     'cross_street': 'btwn Folsom & Harrison St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '85 Columbia Sq (btwn Folsom & Harrison St), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'Apple Tree Preschool',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '9bc70744a47f47fcf5fb31ce',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 893,
#    'geocodes': {'drop_off': {'latitude': 37.760542, 'longitude': -122.396346},
#     'main': {'latitude': 37.760587, 'longitude': -122.395863},
#     'roof': {'latitude': 37.760587, 'longitude': -122.395863}},
#    'link': '/v3/places/9bc70744a47f47fcf5fb31ce',
#    'location': {'address': '465 Missouri St',
#     'census_block': '060750227022008',
#     'country': 'US',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '465 Missouri St, San Francisco, CA 94107',
#     'locality': 'San Francisco',
#     'postcode': '94107',
#     'region': 'CA'},
#    'name': 'Potrero Kids Daniel Webster Preschool',
#    'related_places': {}},
#   {'fsq_id': '5d01b4403c858d002c2e1b52',
#    'categories': [{'id': 11025,
#      'name': 'Child Care Service',
#      'short_name': 'Child Care',
#      'plural_name': 'Child Care Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#       'suffix': '.png'}},
#     {'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 658,
#    'geocodes': {'main': {'latitude': 37.771043, 'longitude': -122.404865},
#     'roof': {'latitude': 37.771043, 'longitude': -122.404865}},
#    'link': '/v3/places/5d01b4403c858d002c2e1b52',
#    'location': {'address': '633 8th St',
#     'census_block': '060750180003001',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '633 8th St, San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'Studio Montessori',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': 'c52df4e1d8c14179d4bf7365',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 1488,
#    'geocodes': {'drop_off': {'latitude': 37.751921, 'longitude': -122.406299},
#     'main': {'latitude': 37.751894, 'longitude': -122.406603},
#     'roof': {'latitude': 37.751894, 'longitude': -122.406603}},
#    'link': '/v3/places/c52df4e1d8c14179d4bf7365',
#    'location': {'address': '1294 Potrero Ave',
#     'census_block': '060750229031005',
#     'country': 'US',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '1294 Potrero Ave, San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'Good Samaritan Preschool',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 37.765158,
#      'longitude': -122.404234},
#     'radius': 2000}}}}

# %%
near_child_school = []
for venue in child_school["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    near_child_school.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

child_school_df = pd.DataFrame(near_child_school)

child_school_df
# Out:
#                                     Name   Latitude   Longitude  Distance
# 0              Petite Explorer Preschool  37.761362 -122.417410      1229
# 1                   Apple Tree Preschool  37.777038 -122.405075      1313
# 2  Potrero Kids Daniel Webster Preschool  37.760587 -122.395863       893
# 3                      Studio Montessori  37.771043 -122.404865       658
# 4               Good Samaritan Preschool  37.751894 -122.406603      1488

# %%
# Creating a map centered around a location of child school 
m = folium.Map(location=[child_school_df.iloc[0]['Latitude'], child_school_df.iloc[0]['Longitude']], zoom_start=12)

for index, row in child_school_df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [37.765158, -122.404234]
folium.Marker(company_location, 
              tooltip='Zynga',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ba8c3012b3c0c75bdbdfbb7fc993e36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ba8c3012b3c0c75bdbdfbb7fc993e36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ba8c3012b3c0c75bdbdfbb7fc993e36 = L.map(
#                 &quot;map_9ba8c3012b3c0c75bdbdfbb7fc993e36&quot;,
#                 {
#                     center: [37.761362, -122.41741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d531ce560ebe6bf8739a0746afca9e6b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9ba8c3012b3c0c75bdbdfbb7fc993e36);
#
#
#             var marker_a80f6ad6978dc174a744c0e91dbfcfcc = L.marker(
#                 [37.761362, -122.41741],
#                 {}
#             ).addTo(map_9ba8c3012b3c0c75bdbdfbb7fc993e36);
#
#
#             var icon_4556714ab66440c4e3c3ffc9332c4acf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a80f6ad6978dc174a744c0e91dbfcfcc.setIcon(icon_4556714ab66440c4e3c3ffc9332c4acf);
#
#
#             marker_a80f6ad6978dc174a744c0e91dbfcfcc.bindTooltip(
#                 `&lt;div&gt;
#                      Petite Explorer Preschool
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_17d4882a0f745e711a25ecc52f936f70 = L.marker(
#                 [37.777038, -122.405075],
#                 {}
#             ).addTo(map_9ba8c3012b3c0c75bdbdfbb7fc993e36);
#
#
#             var icon_40609566c846283e2afa742a183571e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_17d4882a0f745e711a25ecc52f936f70.setIcon(icon_40609566c846283e2afa742a183571e0);
#
#
#             marker_17d4882a0f745e711a25ecc52f936f70.bindTooltip(
#                 `&lt;div&gt;
#                      Apple Tree Preschool
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5630c0cc997bf59811ae90c805c0a180 = L.marker(
#                 [37.760587, -122.395863],
#                 {}
#             ).addTo(map_9ba8c3012b3c0c75bdbdfbb7fc993e36);
#
#
#             var icon_35a9ef80c9ff82b801d820ac0414137f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5630c0cc997bf59811ae90c805c0a180.setIcon(icon_35a9ef80c9ff82b801d820ac0414137f);
#
#
#             marker_5630c0cc997bf59811ae90c805c0a180.bindTooltip(
#                 `&lt;div&gt;
#                      Potrero Kids Daniel Webster Preschool
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c13787cd99a9a62acb069e7d4dd4f13a = L.marker(
#                 [37.771043, -122.404865],
#                 {}
#             ).addTo(map_9ba8c3012b3c0c75bdbdfbb7fc993e36);
#
#
#             var icon_6ee66f874244d0180d151dc3b578df50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c13787cd99a9a62acb069e7d4dd4f13a.setIcon(icon_6ee66f874244d0180d151dc3b578df50);
#
#
#             marker_c13787cd99a9a62acb069e7d4dd4f13a.bindTooltip(
#                 `&lt;div&gt;
#                      Studio Montessori
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_617d704c37f1c4b93af830312ed0eb99 = L.marker(
#                 [37.751894, -122.406603],
#                 {}
#             ).addTo(map_9ba8c3012b3c0c75bdbdfbb7fc993e36);
#
#
#             var icon_b5318df2edce0dd3d1d262cf86bc7f11 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&q

# %%
# checking for close Starbucks

def requests_for_foursquare (query, lat, lon, radius=2000, limit=1):
    lat = 37.765158
    lon = -122.404234 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
starbucks = requests_for_foursquare ("Starbucks", lat, lon, radius=1000, limit=5)
starbucks
# Out:
# {'results': [{'fsq_id': '4a55303af964a520d0b31fe3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 105,
#    'geocodes': {'main': {'latitude': 37.765796, 'longitude': -122.403409},
#     'roof': {'latitude': 37.765796, 'longitude': -122.403409}},
#    'link': '/v3/places/4a55303af964a520d0b31fe3',
#    'location': {'address': '350 Rhode Island St',
#     'address_extended': 'Ste 120',
#     'census_block': '060750607021028',
#     'country': 'US',
#     'cross_street': 'at 16th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '350 Rhode Island St (at 16th St), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '5ccbe7c766fc65002cf4bcd3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 493,
#    'geocodes': {'main': {'latitude': 37.766862, 'longitude': -122.409564},
#     'roof': {'latitude': 37.766862, 'longitude': -122.409564}},
#    'link': '/v3/places/5ccbe7c766fc65002cf4bcd3',
#    'location': {'address': '2300 16th St',
#     'census_block': '060750177001015',
#     'country': 'US',
#     'cross_street': 'Between Bryant St & Potrero Ave',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '2300 16th St (Between Bryant St & Potrero Ave), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {'parent': {'fsq_id': '49dcfdb3f964a520dd5f1fe3',
#      'categories': [{'id': 17069,
#        'name': 'Grocery Store',
#        'short_name': 'Grocery Store',
#        'plural_name': 'Grocery Stores',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#         'suffix': '.png'}}],
#      'name': 'Safeway'}},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4aca4f0bf964a5205ac120e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 935,
#    'geocodes': {'main': {'latitude': 37.767121, 'longitude': -122.393738},
#     'roof': {'latitude': 37.767121, 'longitude': -122.393738}},
#    'link': '/v3/places/4aca4f0bf964a5205ac120e3',
#    'location': {'address': '1700 Owens St',
#     'census_block': '060750607013015',
#     'country': 'US',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '1700 Owens St, San Francisco, CA 94158',
#     'locality': 'San Francisco',
#     'postcode': '94158',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4a1e071af964a520bb7b1fe3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 600,
#    'geocodes': {'drop_off': {'latitude': 37.763021, 'longitude': -122.410556},
#     'main': {'latitude': 37.762898, 'longitude': -122.410549},
#     'roof': {'latitude': 37.762898, 'longitude': -122.410549}},
#    'link': '/v3/places/4a1e071af964a520bb7b1fe3',
#    'location': {'address': '2727 Mariposa St',
#     'census_block': '060750228011013',
#     'country': 'US',
#     'cross_street': 'at Bryant St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '2727 Mariposa St (at Bryant St), San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '49bd6c9ef964a5207a541fe3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 575,
#    'geocodes': {'main': {'latitude': 37.770294, 'longitude': -122.403435}},
#    'link': '/v3/places/49bd6c9ef964a5207a541fe3',
#    'location': {'address': '689 Townsend St',
#     'census_block': '060750607021004',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '689 Townsend St, San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 37.765158,
#      'longitude': -122.404234},
#     'radius': 1000}}}}

# %%
near_starbucks = []
for venue in starbucks["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    near_starbucks.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

starbucks_df = pd.DataFrame(near_starbucks)

starbucks_df
# Out:
#         Name   Latitude   Longitude  Distance
# 0  Starbucks  37.765796 -122.403409       105
# 1  Starbucks  37.766862 -122.409564       493
# 2  Starbucks  37.767121 -122.393738       935
# 3  Starbucks  37.762898 -122.410549       600
# 4  Starbucks  37.770294 -122.403435       575

# %%
# Creating a map centered around a location of Starbucks
m = folium.Map(location=[starbucks_df.iloc[0]['Latitude'], starbucks_df.iloc[0]['Longitude']], zoom_start=12)

for index, row in starbucks_df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [37.765158, -122.404234]
folium.Marker(company_location, 
              tooltip='Zynga',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_544dda30a533f6dfaff39c2d322c33cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_544dda30a533f6dfaff39c2d322c33cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_544dda30a533f6dfaff39c2d322c33cd = L.map(
#                 &quot;map_544dda30a533f6dfaff39c2d322c33cd&quot;,
#                 {
#                     center: [37.765796, -122.403409],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25809f413ee3b4259a59186114fc0344 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_544dda30a533f6dfaff39c2d322c33cd);
#
#
#             var marker_1dac3518c98c3260d84b6772417858b3 = L.marker(
#                 [37.765796, -122.403409],
#                 {}
#             ).addTo(map_544dda30a533f6dfaff39c2d322c33cd);
#
#
#             var icon_b66d3d10a2082e4b66d19bfbe787e7e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1dac3518c98c3260d84b6772417858b3.setIcon(icon_b66d3d10a2082e4b66d19bfbe787e7e0);
#
#
#             marker_1dac3518c98c3260d84b6772417858b3.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_37d3180f4bd6697dbccda2e983db36e1 = L.marker(
#                 [37.766862, -122.409564],
#                 {}
#             ).addTo(map_544dda30a533f6dfaff39c2d322c33cd);
#
#
#             var icon_0ff82dbdf171b3a788e3e04137cf4b32 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_37d3180f4bd6697dbccda2e983db36e1.setIcon(icon_0ff82dbdf171b3a788e3e04137cf4b32);
#
#
#             marker_37d3180f4bd6697dbccda2e983db36e1.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_913d32f10b6b3b908528617474b95e6c = L.marker(
#                 [37.767121, -122.393738],
#                 {}
#             ).addTo(map_544dda30a533f6dfaff39c2d322c33cd);
#
#
#             var icon_71236701486110b33c1ff0567670189c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_913d32f10b6b3b908528617474b95e6c.setIcon(icon_71236701486110b33c1ff0567670189c);
#
#
#             marker_913d32f10b6b3b908528617474b95e6c.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c05f27b2e19e0ce4d0c348a54be1dd57 = L.marker(
#                 [37.762898, -122.410549],
#                 {}
#             ).addTo(map_544dda30a533f6dfaff39c2d322c33cd);
#
#
#             var icon_fbd4409a34d22c362441967d1eed2c7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c05f27b2e19e0ce4d0c348a54be1dd57.setIcon(icon_fbd4409a34d22c362441967d1eed2c7b);
#
#
#             marker_c05f27b2e19e0ce4d0c348a54be1dd57.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1f810bf68aa09604e6f0dd4916309131 = L.marker(
#                 [37.770294, -122.403435],
#                 {}
#             ).addTo(map_544dda30a533f6dfaff39c2d322c33cd);
#
#
#             var icon_9e9b53c13ce11dcff45a9a13a3f74ddb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f810bf68aa09604e6f0d

# %%
# checking for close Vegan Restaurants

def requests_for_foursquare (query, lat, lon, radius=1000, limit=1):
    lat = 37.765158
    lon = -122.404234 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
vegan_restaurant = requests_for_foursquare ("Vegan", lat, lon, radius=1000, limit=5)
vegan_restaurant
# Out:
# {'results': [{'fsq_id': '475fbd10f964a520de4c1fe3',
#    'categories': [{'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'c356152c-f98c-4c43-8a1e-1d16cc9ea1c8',
#      'name': 'Whole Foods'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 167,
#    'geocodes': {'main': {'latitude': 37.764381, 'longitude': -122.40268},
#     'roof': {'latitude': 37.764381, 'longitude': -122.40268}},
#    'link': '/v3/places/475fbd10f964a520de4c1fe3',
#    'location': {'address': '450 Rhode Island St',
#     'census_block': '060750227041003',
#     'country': 'US',
#     'cross_street': 'at 17th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '450 Rhode Island St (at 17th St), San Francisco, CA 94107',
#     'locality': 'San Francisco',
#     'postcode': '94107',
#     'region': 'CA'},
#    'name': 'Whole Foods',
#    'related_places': {'children': [{'fsq_id': '58a5d1b2739d851f18993c9b',
#       'categories': [{'id': 13035,
#         'name': 'Coffee Shop',
#         'short_name': 'Coffee Shop',
#         'plural_name': 'Coffee Shops',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'}}],
#       'name': 'Allegro Coffee Company'}]},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '49b1a93df964a520d9521fe3',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 992,
#    'geocodes': {'drop_off': {'latitude': 37.763272, 'longitude': -122.415127},
#     'main': {'latitude': 37.763254, 'longitude': -122.4153},
#     'roof': {'latitude': 37.763254, 'longitude': -122.4153}},
#    'link': '/v3/places/49b1a93df964a520d9521fe3',
#    'location': {'address': '2128 Folsom St',
#     'census_block': '060750228011006',
#     'country': 'US',
#     'cross_street': 'btwn 17th & 18th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '2128 Folsom St (btwn 17th & 18th St), San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'Stable Cafe',
#    'related_places': {'children': []},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4fc7c071e4b06e4ecff8e93d',
#    'categories': [{'id': 14013,
#      'name': 'Street Food Gathering',
#      'short_name': 'Street Food Gathering',
#      'plural_name': 'Street Food Gatherings',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 827,
#    'geocodes': {'main': {'latitude': 37.769745, 'longitude': -122.412028},
#     'roof': {'latitude': 37.769745, 'longitude': -122.412028}},
#    'link': '/v3/places/4fc7c071e4b06e4ecff8e93d',
#    'location': {'address': '428 11th St',
#     'census_block': '060750177001007',
#     'country': 'US',
#     'cross_street': 'at Division St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '428 11th St (at Division St), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'SOMA StrEat Food Park',
#    'related_places': {'children': [{'fsq_id': '59b025c6018cbb2d4cdd23ea',
#       'categories': [{'id': 13000,
#         'name': 'Dining and Drinking',
#         'short_name': 'Dining and Drinking',
#         'plural_name': 'Dining and Drinking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'}}],
#       'name': 'Cochinita'},
#      {'fsq_id': '51422894e4b0158def8aea54',
#       'categories': [{'id': 13064,
#         'name': 'Pizzeria',
#         'short_name': 'Pizza',
#         'plural_name': 'Pizzerias',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'}}],
#       'name': 'Firetrail Pizza'},
#      {'fsq_id': '5025567ee4b0c6da26677c3c',
#       'categories': [{'id': 13000,
#         'name': 'Dining and Drinking',
#         'short_name': 'Dining and Drinking',
#         'plural_name': 'Dining and Drinking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'}}],
#       'name': 'Mama Cass'},
#      {'fsq_id': '559c4792498e284399489148',
#       'categories': [{'id': 13000,
#         'name': 'Dining and Drinking',
#         'short_name': 'Dining and Drinking',
#         'plural_name': 'Dining and Drinking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'}}],
#       'name': "Izzy's Cheesesteaks"},
#      {'fsq_id': '5f5188211f1b1f180a22a3e5',
#       'categories': [{'id': 11062,
#         'name': 'Barbershop',
#         'short_name': 'Barbershop',
#         'plural_name': 'Barbershops',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#          'suffix': '.png'}}],
#       'name': 'The Barber Collective'}]},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '413e4b80f964a520521c1fe3',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'short_name': 'Pizza',
#      'plural_name': 'Pizzerias',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 652,
#    'geocodes': {'main': {'latitude': 37.762371, 'longitude': -122.39776},
#     'roof': {'latitude': 37.762371, 'longitude': -122.39776}},
#    'link': '/v3/places/413e4b80f964a520521c1fe3',
#    'location': {'address': '300 Connecticut St',
#     'census_block': '060750227022005',
#     'country': 'US',
#     'cross_street': 'at 18th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '300 Connecticut St (at 18th St), San Francisco, CA 94107',
#     'locality': 'San Francisco',
#     'postcode': '94107',
#     'region': 'CA'},
#    'name': 'Goat Hill Pizza',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4085b980f964a5208bf21ee3',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Spot',
#      'short_name': 'Sandwich Spot',
#      'plural_name': 'Sandwich Spots',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 934,
#    'geocodes': {'main': {'latitude': 37.758973, 'longitude': -122.411464},
#     'roof': {'latitude': 37.758973, 'longitude': -122.411464}},
#    'link': '/v3/places/4085b980f964a5208bf21ee3',
#    'location': {'address': '3049 20th St',
#     'census_block': '060750228012006',
#     'country': 'US',
#     'cross_street': 'at Alabama St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '3049 20th St (at Alabama St), San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'Atlas Cafe',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 37.765158,
#      'longitude': -122.404234},
#     'radius': 1000}}}}

# %%
vegan = []
for venue in vegan_restaurant["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    vegan.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

vegan_restaurant_df = pd.DataFrame(vegan)

vegan_restaurant_df
# Out:
#                     Name   Latitude   Longitude  Distance
# 0            Whole Foods  37.764381 -122.402680       167
# 1            Stable Cafe  37.763254 -122.415300       992
# 2  SOMA StrEat Food Park  37.769745 -122.412028       827
# 3        Goat Hill Pizza  37.762371 -122.397760       652
# 4             Atlas Cafe  37.758973 -122.411464       934

# %%
# Creating a map centered around a location of vegan restaurant
m = folium.Map(location=[vegan_restaurant_df.iloc[0]['Latitude'], vegan_restaurant_df.iloc[0]['Longitude']], zoom_start=13)

for index, row in vegan_restaurant_df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [37.765158, -122.404234]
folium.Marker(company_location, 
              tooltip='Zynga',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e392cfe26fd3fdfa68103d6988e2bc95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e392cfe26fd3fdfa68103d6988e2bc95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e392cfe26fd3fdfa68103d6988e2bc95 = L.map(
#                 &quot;map_e392cfe26fd3fdfa68103d6988e2bc95&quot;,
#                 {
#                     center: [37.764381, -122.40268],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cf37f82a43cd1b17d7a6455d3c67e3f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e392cfe26fd3fdfa68103d6988e2bc95);
#
#
#             var marker_0c582fa7a12f181a79cb111a1546375a = L.marker(
#                 [37.764381, -122.40268],
#                 {}
#             ).addTo(map_e392cfe26fd3fdfa68103d6988e2bc95);
#
#
#             var icon_8debf128f6f6efce0de1161d302dc13b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c582fa7a12f181a79cb111a1546375a.setIcon(icon_8debf128f6f6efce0de1161d302dc13b);
#
#
#             marker_0c582fa7a12f181a79cb111a1546375a.bindTooltip(
#                 `&lt;div&gt;
#                      Whole Foods
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2fe836b756c0c713d07dadff5439af0 = L.marker(
#                 [37.763254, -122.4153],
#                 {}
#             ).addTo(map_e392cfe26fd3fdfa68103d6988e2bc95);
#
#
#             var icon_d8df4c0d509adc81a74be3b0b9152ece = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b2fe836b756c0c713d07dadff5439af0.setIcon(icon_d8df4c0d509adc81a74be3b0b9152ece);
#
#
#             marker_b2fe836b756c0c713d07dadff5439af0.bindTooltip(
#                 `&lt;div&gt;
#                      Stable Cafe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ebfeb8da0140bda4017000c9e42bbdb = L.marker(
#                 [37.769745, -122.412028],
#                 {}
#             ).addTo(map_e392cfe26fd3fdfa68103d6988e2bc95);
#
#
#             var icon_eba47c0df84d5039be9cdf8b3f896bf3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ebfeb8da0140bda4017000c9e42bbdb.setIcon(icon_eba47c0df84d5039be9cdf8b3f896bf3);
#
#
#             marker_3ebfeb8da0140bda4017000c9e42bbdb.bindTooltip(
#                 `&lt;div&gt;
#                      SOMA StrEat Food Park
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0761e251abd91fac2bd6df9a9353e7af = L.marker(
#                 [37.762371, -122.39776],
#                 {}
#             ).addTo(map_e392cfe26fd3fdfa68103d6988e2bc95);
#
#
#             var icon_12f3db85495c180abb818788395957f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0761e251abd91fac2bd6df9a9353e7af.setIcon(icon_12f3db85495c180abb818788395957f7);
#
#
#             marker_0761e251abd91fac2bd6df9a9353e7af.bindTooltip(
#                 `&lt;div&gt;
#                      Goat Hill Pizza
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd97d36dc71a27986e5700acee53d2a9 = L.marker(
#                 [37.758973, -122.411464],
#                 {}
#             ).addTo(map_e392cfe26fd3fdfa68103d6988e2bc95);
#
#
#             var icon_504f3282ab9848bd03da9911403a8182 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dd97

# %%
# checking for close Basketball Stadium 


def requests_for_foursquare (query, lat, lon, radius=1000, limit=1):
    lat = 37.765158
    lon = -122.404234 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
basketball_stadium = requests_for_foursquare ("basketball", lat, lon, radius=1000, limit=5)
basketball_stadium
# Out:
# {'results': [{'fsq_id': '4bf5e710004ed13a55a441a0',
#    'categories': [{'id': 10000,
#      'name': 'Arts and Entertainment',
#      'short_name': 'Arts & Entertainment',
#      'plural_name': 'Arts and Entertainment',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'}},
#     {'id': 18008,
#      'name': 'Basketball Court',
#      'short_name': 'Basketball Court',
#      'plural_name': 'Basketball Courts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 932,
#    'geocodes': {'main': {'latitude': 37.77208, 'longitude': -122.397686}},
#    'link': '/v3/places/4bf5e710004ed13a55a441a0',
#    'location': {'address': 'Berry St',
#     'census_block': '060750607033005',
#     'country': 'US',
#     'cross_street': 'I-280',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': 'Berry St (I-280), San Francisco, CA 94158',
#     'locality': 'San Francisco',
#     'postcode': '94158',
#     'region': 'CA'},
#    'name': 'Berry Basketball Courts',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '51a0fac8498ed4464614a9ed',
#    'categories': [{'id': 18008,
#      'name': 'Basketball Court',
#      'short_name': 'Basketball Court',
#      'plural_name': 'Basketball Courts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 987,
#    'geocodes': {'main': {'latitude': 37.759168, 'longitude': -122.412335},
#     'roof': {'latitude': 37.759168, 'longitude': -122.412335}},
#    'link': '/v3/places/51a0fac8498ed4464614a9ed',
#    'location': {'address': '20TH St',
#     'census_block': '060750228012004',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '20TH St, San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'NBA Nation',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4acab409f964a520dac220e3',
#    'categories': [{'id': 16037,
#      'name': 'Playground',
#      'short_name': 'Playground',
#      'plural_name': 'Playgrounds',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 420,
#    'geocodes': {'main': {'latitude': 37.763975, 'longitude': -122.399001},
#     'roof': {'latitude': 37.763975, 'longitude': -122.399001}},
#    'link': '/v3/places/4acab409f964a520dac220e3',
#    'location': {'address': '1501 17th St',
#     'census_block': '060750227041000',
#     'country': 'US',
#     'cross_street': 'btw Arkansas & Carolina',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '1501 17th St (btw Arkansas & Carolina), San Francisco, CA 94107',
#     'locality': 'San Francisco',
#     'postcode': '94107',
#     'region': 'CA'},
#    'name': 'Jackson Playground',
#    'related_places': {'children': []},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4a8c1959f964a520f60c20e3',
#    'categories': [{'id': 16037,
#      'name': 'Playground',
#      'short_name': 'Playground',
#      'plural_name': 'Playgrounds',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 1245,
#    'geocodes': {'main': {'latitude': 37.770963, 'longitude': -122.398624},
#     'roof': {'latitude': 37.770963, 'longitude': -122.398624}},
#    'link': '/v3/places/4a8c1959f964a520f60c20e3',
#    'location': {'address': '451 Berry St',
#     'census_block': '060750607021002',
#     'country': 'US',
#     'cross_street': 'at 4th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '451 Berry St (at 4th St), San Francisco, CA 94158',
#     'locality': 'San Francisco',
#     'postcode': '94158',
#     'region': 'CA'},
#    'name': 'Mission Creek Park',
#    'related_places': {'children': [{'fsq_id': '4ae79cb4f964a520d0ac21e3',
#       'categories': [{'id': 16033,
#         'name': 'Dog Park',
#         'short_name': 'Dog Park',
#         'plural_name': 'Dog Parks',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#          'suffix': '.png'}}],
#       'name': 'Mission Creek Dog Park'}]},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4fc7c071e4b06e4ecff8e93d',
#    'categories': [{'id': 14013,
#      'name': 'Street Food Gathering',
#      'short_name': 'Street Food Gathering',
#      'plural_name': 'Street Food Gatherings',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 827,
#    'geocodes': {'main': {'latitude': 37.769745, 'longitude': -122.412028},
#     'roof': {'latitude': 37.769745, 'longitude': -122.412028}},
#    'link': '/v3/places/4fc7c071e4b06e4ecff8e93d',
#    'location': {'address': '428 11th St',
#     'census_block': '060750177001007',
#     'country': 'US',
#     'cross_street': 'at Division St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '428 11th St (at Division St), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'SOMA StrEat Food Park',
#    'related_places': {'children': [{'fsq_id': '59b025c6018cbb2d4cdd23ea',
#       'categories': [{'id': 13000,
#         'name': 'Dining and Drinking',
#         'short_name': 'Dining and Drinking',
#         'plural_name': 'Dining and Drinking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'}}],
#       'name': 'Cochinita'},
#      {'fsq_id': '51422894e4b0158def8aea54',
#       'categories': [{'id': 13064,
#         'name': 'Pizzeria',
#         'short_name': 'Pizza',
#         'plural_name': 'Pizzerias',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'}}],
#       'name': 'Firetrail Pizza'},
#      {'fsq_id': '5025567ee4b0c6da26677c3c',
#       'categories': [{'id': 13000,
#         'name': 'Dining and Drinking',
#         'short_name': 'Dining and Drinking',
#         'plural_name': 'Dining and Drinking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'}}],
#       'name': 'Mama Cass'},
#      {'fsq_id': '559c4792498e284399489148',
#       'categories': [{'id': 13000,
#         'name': 'Dining and Drinking',
#         'short_name': 'Dining and Drinking',
#         'plural_name': 'Dining and Drinking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'}}],
#       'name': "Izzy's Cheesesteaks"},
#      {'fsq_id': '5f5188211f1b1f180a22a3e5',
#       'categories': [{'id': 11062,
#         'name': 'Barbershop',
#         'short_name': 'Barbershop',
#         'plural_name': 'Barbershops',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#          'suffix': '.png'}}],
#       'name': 'The Barber Collective'}]},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 37.765158,
#      'longitude': -122.404234},
#     'radius': 1000}}}}

# %%
basketball = []
for venue in basketball_stadium["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    basketball.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

basketball_stadium_df = pd.DataFrame(basketball)

basketball_stadium_df
# Out:
#                       Name   Latitude   Longitude  Distance
# 0  Berry Basketball Courts  37.772080 -122.397686       932
# 1               NBA Nation  37.759168 -122.412335       987
# 2       Jackson Playground  37.763975 -122.399001       420
# 3       Mission Creek Park  37.770963 -122.398624      1245
# 4    SOMA StrEat Food Park  37.769745 -122.412028       827

# %%
# Creating a map centered around a location of basketball stadium
m = folium.Map(location=[basketball_stadium_df.iloc[0]['Latitude'], basketball_stadium_df.iloc[0]['Longitude']], zoom_start=12)

for index, row in basketball_stadium_df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [37.765158, -122.404234]
folium.Marker(company_location, 
              tooltip='Zynga',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe83d8cbd028937af678c63691ecb2c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe83d8cbd028937af678c63691ecb2c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe83d8cbd028937af678c63691ecb2c1 = L.map(
#                 &quot;map_fe83d8cbd028937af678c63691ecb2c1&quot;,
#                 {
#                     center: [37.77208, -122.397686],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7f77b65ace67b7904c63570b52f9961 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe83d8cbd028937af678c63691ecb2c1);
#
#
#             var marker_2b22ed85d85265ca1549965638d9412f = L.marker(
#                 [37.77208, -122.397686],
#                 {}
#             ).addTo(map_fe83d8cbd028937af678c63691ecb2c1);
#
#
#             var icon_619d32d1d1f091fc2e49b052cee8c84d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b22ed85d85265ca1549965638d9412f.setIcon(icon_619d32d1d1f091fc2e49b052cee8c84d);
#
#
#             marker_2b22ed85d85265ca1549965638d9412f.bindTooltip(
#                 `&lt;div&gt;
#                      Berry Basketball Courts
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_abe8ec25d9b18ce8db7f572ad1ebe952 = L.marker(
#                 [37.759168, -122.412335],
#                 {}
#             ).addTo(map_fe83d8cbd028937af678c63691ecb2c1);
#
#
#             var icon_f4899cd6faafc5c6cb11318b7845ef04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abe8ec25d9b18ce8db7f572ad1ebe952.setIcon(icon_f4899cd6faafc5c6cb11318b7845ef04);
#
#
#             marker_abe8ec25d9b18ce8db7f572ad1ebe952.bindTooltip(
#                 `&lt;div&gt;
#                      NBA Nation
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8302bf0a42d1f24de8bcbd111d053c20 = L.marker(
#                 [37.763975, -122.399001],
#                 {}
#             ).addTo(map_fe83d8cbd028937af678c63691ecb2c1);
#
#
#             var icon_6b1dda698cef6b35cdefea1e8782c2f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8302bf0a42d1f24de8bcbd111d053c20.setIcon(icon_6b1dda698cef6b35cdefea1e8782c2f9);
#
#
#             marker_8302bf0a42d1f24de8bcbd111d053c20.bindTooltip(
#                 `&lt;div&gt;
#                      Jackson Playground
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_88121fe3ff8de39831be9f47458bbc25 = L.marker(
#                 [37.770963, -122.398624],
#                 {}
#             ).addTo(map_fe83d8cbd028937af678c63691ecb2c1);
#
#
#             var icon_82960ad0c48aa4cbbeb9a1eb81a5e001 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88121fe3ff8de39831be9f47458bbc25.setIcon(icon_82960ad0c48aa4cbbeb9a1eb81a5e001);
#
#
#             marker_88121fe3ff8de39831be9f47458bbc25.bindTooltip(
#                 `&lt;div&gt;
#                      Mission Creek Park
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ef8cc7a8cb10ea7726d16e318060dc76 = L.marker(
#                 [37.769745, -122.412028],
#                 {}
#             ).addTo(map_fe83d8cbd028937af678c63691ecb2c1);
#
#
#             var icon_5c6f9359be173a78fc05b779b94eaa25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %%
# checking for close Pet Store 


def requests_for_foursquare (query, lat, lon, radius=1000, limit=1):
    lat = 37.765158
    lon = -122.404234 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
pet_shop = requests_for_foursquare ("Pet Store", lat, lon, radius=1000, limit=5)
pet_shop
# Out:
# {'results': [{'fsq_id': '4a21b55df964a520327d1fe3',
#    'categories': [{'id': 11134,
#      'name': 'Pet Grooming Service',
#      'short_name': 'Pet Grooming Service',
#      'plural_name': 'Pet Grooming Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#       'suffix': '.png'}},
#     {'id': 17110,
#      'name': 'Pet Supplies Store',
#      'short_name': 'Pet Supplies Store',
#      'plural_name': 'Pet Supplies Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 862,
#    'geocodes': {'drop_off': {'latitude': 37.76412, 'longitude': -122.394544},
#     'main': {'latitude': 37.764155, 'longitude': -122.394496},
#     'roof': {'latitude': 37.764155, 'longitude': -122.394496}},
#    'link': '/v3/places/4a21b55df964a520327d1fe3',
#    'location': {'address': '199 Mississippi St',
#     'census_block': '060750227021001',
#     'country': 'US',
#     'cross_street': 'at Mariposa St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '199 Mississippi St (at Mariposa St), San Francisco, CA 94107',
#     'locality': 'San Francisco',
#     'postcode': '94107',
#     'region': 'CA'},
#    'name': 'Pawtrero Hill BathHouse & Feed',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4aa72aeef964a520154c20e3',
#    'categories': [{'id': 17110,
#      'name': 'Pet Supplies Store',
#      'short_name': 'Pet Supplies Store',
#      'plural_name': 'Pet Supplies Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'}}],
#    'chains': [{'id': '40ac1d6f-112b-4664-be82-8f563190b1c8', 'name': 'Petco'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 540,
#    'geocodes': {'main': {'latitude': 37.766509, 'longitude': -122.410332},
#     'roof': {'latitude': 37.766509, 'longitude': -122.410332}},
#    'link': '/v3/places/4aa72aeef964a520154c20e3',
#    'location': {'address': '2300 16th St',
#     'address_extended': 'Ste 200',
#     'census_block': '060750177001015',
#     'country': 'US',
#     'cross_street': 'btw Bryant St & Potrero Ave',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '2300 16th St (btw Bryant St & Potrero Ave), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': 'Petco',
#    'related_places': {'parent': {'fsq_id': '49c99371f964a5207d581fe3',
#      'categories': [{'id': 17114,
#        'name': 'Shopping Mall',
#        'short_name': 'Mall',
#        'plural_name': 'Shopping Malls',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#         'suffix': '.png'}}],
#      'name': 'Potrero Center'}},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '5edfe899d737db2f29e56894',
#    'categories': [{'id': 17110,
#      'name': 'Pet Supplies Store',
#      'short_name': 'Pet Supplies Store',
#      'plural_name': 'Pet Supplies Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 721,
#    'geocodes': {'drop_off': {'latitude': 37.761252, 'longitude': -122.411059},
#     'main': {'latitude': 37.761277, 'longitude': -122.410811},
#     'roof': {'latitude': 37.761277, 'longitude': -122.410811}},
#    'link': '/v3/places/5edfe899d737db2f29e56894',
#    'location': {'address': '607 Florida St',
#     'census_block': '060750228011018',
#     'country': 'US',
#     'cross_street': '18th St',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '607 Florida St (18th St), San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'George',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4c237f9413c00f474e1c89de',
#    'categories': [{'id': 11134,
#      'name': 'Pet Grooming Service',
#      'short_name': 'Pet Grooming Service',
#      'plural_name': 'Pet Grooming Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#       'suffix': '.png'}},
#     {'id': 17110,
#      'name': 'Pet Supplies Store',
#      'short_name': 'Pet Supplies Store',
#      'plural_name': 'Pet Supplies Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 796,
#    'geocodes': {'main': {'latitude': 37.766882, 'longitude': -122.412719},
#     'roof': {'latitude': 37.766882, 'longitude': -122.412719}},
#    'link': '/v3/places/4c237f9413c00f474e1c89de',
#    'location': {'address': '1200 15th St',
#     'census_block': '060750177001012',
#     'country': 'US',
#     'cross_street': 'Harrison',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '1200 15th St (Harrison), San Francisco, CA 94103',
#     'locality': 'San Francisco',
#     'postcode': '94103',
#     'region': 'CA'},
#    'name': "Bernie's Grooming",
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4d62c9801ee8721e6ee8c421',
#    'categories': [{'id': 11135,
#      'name': 'Pet Sitting and Boarding Service',
#      'short_name': 'Pet Sitting and Boarding Service',
#      'plural_name': 'Pet Sitting and Boarding Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#       'suffix': '.png'}},
#     {'id': 17110,
#      'name': 'Pet Supplies Store',
#      'short_name': 'Pet Supplies Store',
#      'plural_name': 'Pet Supplies Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 922,
#    'geocodes': {'main': {'latitude': 37.762355, 'longitude': -122.414243},
#     'roof': {'latitude': 37.762355, 'longitude': -122.414243}},
#    'link': '/v3/places/4d62c9801ee8721e6ee8c421',
#    'location': {'address': '3150 18th St',
#     'address_extended': 'Ste 103',
#     'census_block': '060750228011005',
#     'country': 'US',
#     'cross_street': 'Treat Street',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '3150 18th St (Treat Street), San Francisco, CA 94110',
#     'locality': 'San Francisco',
#     'postcode': '94110',
#     'region': 'CA'},
#    'name': 'Mission: Cats',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 37.765158,
#      'longitude': -122.404234},
#     'radius': 1000}}}}

# %%
pet_shop_ = []
for venue in pet_shop["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    pet_shop_.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

pet_shop_df = pd.DataFrame(pet_shop_)

pet_shop_df
# Out:
#                              Name   Latitude   Longitude  Distance
# 0  Pawtrero Hill BathHouse & Feed  37.764155 -122.394496       862
# 1                           Petco  37.766509 -122.410332       540
# 2                          George  37.761277 -122.410811       721
# 3               Bernie's Grooming  37.766882 -122.412719       796
# 4                   Mission: Cats  37.762355 -122.414243       922

# %%
# Creating a map centered around a location of Pet shop
m = folium.Map(location=[pet_shop_df.iloc[0]['Latitude'], pet_shop_df.iloc[0]['Longitude']], zoom_start=12)

for index, row in pet_shop_df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [37.765158, -122.404234]
folium.Marker(company_location, 
              tooltip='Zynga',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3979e407ef6346edbe9f04602aa4a22c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3979e407ef6346edbe9f04602aa4a22c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3979e407ef6346edbe9f04602aa4a22c = L.map(
#                 &quot;map_3979e407ef6346edbe9f04602aa4a22c&quot;,
#                 {
#                     center: [37.764155, -122.394496],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a1f7b9dc828e7353fd1968a25a0c6bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3979e407ef6346edbe9f04602aa4a22c);
#
#
#             var marker_e78f1d2491e2925991ef81dec234eba1 = L.marker(
#                 [37.764155, -122.394496],
#                 {}
#             ).addTo(map_3979e407ef6346edbe9f04602aa4a22c);
#
#
#             var icon_501b9717a331e427e5e35972abb9602d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e78f1d2491e2925991ef81dec234eba1.setIcon(icon_501b9717a331e427e5e35972abb9602d);
#
#
#             marker_e78f1d2491e2925991ef81dec234eba1.bindTooltip(
#                 `&lt;div&gt;
#                      Pawtrero Hill BathHouse &amp; Feed
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c183283e8562efee6a933a0e84cd00b7 = L.marker(
#                 [37.766509, -122.410332],
#                 {}
#             ).addTo(map_3979e407ef6346edbe9f04602aa4a22c);
#
#
#             var icon_bf4fb08803f8d0263b915893c8e807c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c183283e8562efee6a933a0e84cd00b7.setIcon(icon_bf4fb08803f8d0263b915893c8e807c4);
#
#
#             marker_c183283e8562efee6a933a0e84cd00b7.bindTooltip(
#                 `&lt;div&gt;
#                      Petco
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fbb3ff4e1a68ec3e2f4a913f9e1f2776 = L.marker(
#                 [37.761277, -122.410811],
#                 {}
#             ).addTo(map_3979e407ef6346edbe9f04602aa4a22c);
#
#
#             var icon_60f9a55b32934a6d06e2e475023291df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fbb3ff4e1a68ec3e2f4a913f9e1f2776.setIcon(icon_60f9a55b32934a6d06e2e475023291df);
#
#
#             marker_fbb3ff4e1a68ec3e2f4a913f9e1f2776.bindTooltip(
#                 `&lt;div&gt;
#                      George
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d8cdadcc1da8b1d85bb9c0c77bde17c = L.marker(
#                 [37.766882, -122.412719],
#                 {}
#             ).addTo(map_3979e407ef6346edbe9f04602aa4a22c);
#
#
#             var icon_1f2910bdf8bdf06425ab49fb986476e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d8cdadcc1da8b1d85bb9c0c77bde17c.setIcon(icon_1f2910bdf8bdf06425ab49fb986476e6);
#
#
#             marker_9d8cdadcc1da8b1d85bb9c0c77bde17c.bindTooltip(
#                 `&lt;div&gt;
#                      Bernie&#x27;s Grooming
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a72c12ad8cba1d6fca305d0969b22e61 = L.marker(
#                 [37.762355, -122.414243],
#                 {}
#             ).addTo(map_3979e407ef6346edbe9f04602aa4a22c);
#
#
#             var icon_de0267d3c980ea5224caeaf6973ca249 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %%
# checking for close Airport 

def requests_for_foursquare (query, lat, lon, radius=500, limit=1):
    lat = 37.765158
    lon = -122.404234 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
airport = requests_for_foursquare ("International Airport", lat, lon, radius=50000, limit=5)
airport
# Out:
# {'results': [{'fsq_id': '41059b00f964a520850b1fe3',
#    'categories': [{'id': 19031,
#      'name': 'Airport',
#      'short_name': 'Airport',
#      'plural_name': 'Airports',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 16559,
#    'geocodes': {'main': {'latitude': 37.61649, 'longitude': -122.38681}},
#    'link': '/v3/places/41059b00f964a520850b1fe3',
#    'location': {'address_extended': 'Ste 650',
#     'census_block': '060819843001006',
#     'country': 'US',
#     'cross_street': 'at Link Rd',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': 'at Link Rd, San Francisco, CA 94128',
#     'locality': 'San Francisco',
#     'po_box': 'P.O. Box 8097',
#     'postcode': '94128',
#     'region': 'CA'},
#    'name': 'San Francisco International Airport (SFO)',
#    'related_places': {'children': [{'fsq_id': '4db37642316a3bec52549b82',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Domestic Parking Garage E - Short Term/Hourly Parking'},
#      {'fsq_id': '4a7f4289f964a52075f31fe3',
#       'categories': [{'id': 19048,
#         'name': 'Rental Car Location',
#         'short_name': 'Rental Car',
#         'plural_name': 'Rental Car Locations',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#          'suffix': '.png'}}],
#       'name': 'Rental Car Center'},
#      {'fsq_id': '4e021ccc22717718d3a28cd7',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 10R/28L'},
#      {'fsq_id': '4c1fa175eac020a1c3614bc2',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 3'},
#      {'fsq_id': '4db3755f316a3bec525492f3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Domestic Parking Garage C - Short Term/Hourly Parking'},
#      {'fsq_id': '4bb9dbc353649c74364e48fb',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 2'},
#      {'fsq_id': '563fd624cd107e7ca9be2e15',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'SFO Apron'},
#      {'fsq_id': '4adb6ba7f964a520442721e3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'SFO Cell Phone Waiting Lot'},
#      {'fsq_id': '4beac6d96295c9b686ce8608',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Domestic Parking Garage F - Short Term/Hourly Parking'},
#      {'fsq_id': '4ba51a41f964a52085dd38e3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Lot D Overflow Parking'},
#      {'fsq_id': '4bdb6b812a3a0f479d00afb6',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'SFO Executive Terminal'},
#      {'fsq_id': '4ca76aecf47ea143e0686a21',
#       'categories': [{'id': 19031,
#         'name': 'Airport',
#         'short_name': 'Airport',
#         'plural_name': 'Airports',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'SFO AirTrain'},
#      {'fsq_id': '5cae56a01de765002cded237',
#       'categories': [{'id': 19014,
#         'name': 'Hotel',
#         'short_name': 'Hotel',
#         'plural_name': 'Hotels',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#          'suffix': '.png'}}],
#       'name': 'Grand Hyatt At SFO'},
#      {'fsq_id': '57add968498e2d74c294a035',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 1R/19L'},
#      {'fsq_id': '581f85e66401964ad5a636f6',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 10L/28R'},
#      {'fsq_id': '4a9f3c11f964a520fb3c20e3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'SFO Long Term Parking'},
#      {'fsq_id': '4d2089830901721e555f93a5',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'International Terminal'},
#      {'fsq_id': '4db375fc316a3bec525498cb',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Domestic Parking Garage D - Short Term/Hourly Parking'},
#      {'fsq_id': '4db30bde5da3a76f44201863',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Domestic Parking Garage B - Short Term/Hourly Parking'},
#      {'fsq_id': '4bce7946c564ef3b2d71eef0',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Harvey Milk Terminal 1- Departures'},
#      {'fsq_id': '506ca757e4b013f9aa1a0510',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 1L/19R'},
#      {'fsq_id': '468ef191f964a52093481fe3',
#       'categories': [{'id': 19046,
#         'name': 'Metro Station',
#         'short_name': 'Metro',
#         'plural_name': 'Metro Stations',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#          'suffix': '.png'}}],
#       'name': 'San Francisco International Airport BART Station'},
#      {'fsq_id': '4db37abd316a3bec5254c53e',
#       'categories': [{'id': 19038,
#         'name': 'Airport Tram Station',
#         'short_name': 'Airport Tram Station',
#         'plural_name': 'Airport Tram Stations',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_tram_',
#          'suffix': '.png'}}],
#       'name': 'SFO AirTrain Station - Garage G & BART'},
#      {'fsq_id': '4bf5f9744d5f20a12ea098fe',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'SFO Employee Parking Lot C'},
#      {'fsq_id': '4e37340f922e670561038269',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'International Parking Garage A'},
#      {'fsq_id': '4e3735ea922e670561038305',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Garage G'},
#      {'fsq_id': '4db3768b316a3bec52549e66',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Domestic Parking Garage F/G - Short Term/Hourly Parking'},
#      {'fsq_id': '5d935ac06957e600086874f2',
#       'categories': [{'id': 19031,
#         'name': 'Airport',
#         'short_name': 'Airport',
#         'plural_name': 'Airports',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'SFO AirTrain Station - Grand Hyatt at SFO'},
#      {'fsq_id': '4bc0d3774cdfc9b6dd8f9321',
#       'categories': [{'id': 19031,
#         'name': 'Airport',
#         'short_name': 'Airport',
#         'plural_name': 'Airports',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'SFO AirTrain Station - West Field Road'}]},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4493522af964a5207c341fe3',
#    'categories': [{'id': 19031,
#      'name': 'Airport',
#      'short_name': 'Airport',
#      'plural_name': 'Airports',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 17781,
#    'geocodes': {'main': {'latitude': 37.712364, 'longitude': -122.213326},
#     'roof': {'latitude': 37.712395, 'longitude': -122.213323}},
#    'link': '/v3/places/4493522af964a5207c341fe3',
#    'location': {'address': '1 Airport Dr',
#     'address_extended': 'Ste 45',
#     'census_block': '060014090002024',
#     'country': 'US',
#     'dma': 'San Francisco-Oakland-San Jose',
#     'formatted_address': '1 Airport Dr, Oakland, CA 94621',
#     'locality': 'Oakland',
#     'po_box': 'P.O. Box 45',
#     'postcode': '94621',
#     'region': 'CA'},
#    'name': 'Oakland International Airport (OAK)',
#    'related_places': {'children': [{'fsq_id': '4e0b2e5962e1a5e780715430',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 1'},
#      {'fsq_id': '4bd48e61637ba593f0ecf470',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'OAK Apron'},
#      {'fsq_id': '4bf16f2c5f8520a1c4abc07f',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Kaiserair'},
#      {'fsq_id': '4c7ee0851009a09338db454e',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Avitat Executive Air Terminal'},
#      {'fsq_id': '4ceacfb59f776ea89fc76a22',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Daily Parking Lot'},
#      {'fsq_id': '63016747ef3a587510668167',
#       'categories': [{'id': 13003,
#         'name': 'Bar',
#         'short_name': 'Bar',
#         'plural_name': 'Bars',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#          'suffix': '.png'}}],
#       'name': 'Oakland Draft House'},
#      {'fsq_id': '4bd833890b779c74638d06a0',
#       'categories': [{'id': 19031,
#         'name': 'Airport',
#         'short_name': 'Airport',
#         'plural_name': 'Airports',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 2'},
#      {'fsq_id': '4ecd8aa1f5b9832ad6fe7391',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Oakland Air Traffic Control Tower'},
#      {'fsq_id': '54743157498e86777d3420c6',
#       'categories': [{'id': 19000,
#         'name': 'Travel and Transportation',
#         'short_name': 'Travel and Transportation',
#         'plural_name': 'Travel and Transportation',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#          'suffix': '.png'}}],
#       'name': 'BART - Oakland International Airport Station'},
#      {'fsq_id': '4c0e65697189c9285062d8b6',
#       'categories': [{'id': 19030,
#         'name': 'Transport Hub',
#         'short_name': 'Transport Hub',
#         'plural_name': 'Transport Hubs',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Rental Car Shuttle'},
#      {'fsq_id': '64407db35632f27c4e810214',
#       'categories': [{'id': 13303,
#         'name': 'Mexican Restaurant',
#         'short_name': 'Mexican',
#         'plural_name': 'Mexican Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#          'suffix': '.png'}}],
#       'name': 'Calavera at OAK'},
#      {'fsq_id': '4eef67956da153687ce0d053',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway'},
#      {'fsq_id': '4c537dd9a724e21eb78dd1f4',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'FedEx Express Oakland Hub'},
#      {'fsq_id': '4f77ba0de4b09a0a541c6d6d',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Oakland Airport Pick-up'},
#      {'fsq_id': '4c32c07d7cc0c9b695d3f09a',
#       'categories': [{'id': 19048,
#         'name': 'Rental Car Location',
#         'short_name': 'Rental Car',
#         'plural_name': 'Rental Car Locations',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#          'suffix': '.png'}}],
#       'name': 'Rental Car Center'},
#      {'fsq_id': '623dc50796e2321ccb3a7579',
#       'categories': [{'id': 13034,
#         'name': 'Café',
#         'short_name': 'Café',
#         'plural_name': 'Cafés',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'}}],
#       'name': "Farley's Cafe"},
#      {'fsq_id': '58b8f95703cf257b097d58c5',
#       'categories': [{'id': 19049,
#         'name': 'Taxi Stand',
#         'short_name': 'Taxi Stand',
#         'plural_name': 'Taxi Stands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/taxi_',
#          'suffix': '.png'}}],
#       'name': 'Ride App Pickup'},
#      {'fsq_id': '4e499879fa76a0c058c63e8a',
#       'categories': [{'id': 19000,
#         'name': 'Travel and Transportation',
#         'short_name': 'Travel and Transportation',
#         'plural_name': 'Travel and Transportation',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 1/2 Connection Walkway'}]},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 37.765158,
#      'longitude': -122.404234},
#     'radius': 50000}}}}

# %%
airport_ = []
for venue in airport["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    airport_.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

airport_df = pd.DataFrame(airport_)

airport_df
# Out:
#                                         Name   Latitude   Longitude  Distance
# 0  San Francisco International Airport (SFO)  37.616490 -122.386810     16559
# 1        Oakland International Airport (OAK)  37.712364 -122.213326     17781

# %%
# Creating a map centered around a location of an Internation Airport

latitude = 37.765158
longitude = -122.404234

geolocator = Nominatim(user_agent="airport_finder")
airport_coordinates = (37.6213129, -122.3811443)  # San Francisco International Airport (SFO)
company_coordinates = (latitude, longitude)

m = folium.Map(location=company_coordinates, zoom_start=10)

folium.Marker(airport_coordinates, icon=folium.Icon(color='blue'), popup="San Francisco International Airport (SFO)").add_to(m)
folium.Marker(company_coordinates, icon=folium.Icon(color='green'), popup="Company Location").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_335802e04213b24ea102e5d2ffb8c741 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_335802e04213b24ea102e5d2ffb8c741&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_335802e04213b24ea102e5d2ffb8c741 = L.map(
#                 &quot;map_335802e04213b24ea102e5d2ffb8c741&quot;,
#                 {
#                     center: [37.765158, -122.404234],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63a2898d61811ea3d48ed6d321d5e806 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_335802e04213b24ea102e5d2ffb8c741);
#
#
#             var marker_4bb8eb1098d870bf4972bf8a39a3585c = L.marker(
#                 [37.6213129, -122.3811443],
#                 {}
#             ).addTo(map_335802e04213b24ea102e5d2ffb8c741);
#
#
#             var icon_76184eacd43922d1bc8d5778cb1c019e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4bb8eb1098d870bf4972bf8a39a3585c.setIcon(icon_76184eacd43922d1bc8d5778cb1c019e);
#
#
#         var popup_666b91825097a1d6c5855878b0a75c68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dcda50fea46f679de80c59072c9ed9d7 = $(`&lt;div id=&quot;html_dcda50fea46f679de80c59072c9ed9d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco International Airport (SFO)&lt;/div&gt;`)[0];
#                 popup_666b91825097a1d6c5855878b0a75c68.setContent(html_dcda50fea46f679de80c59072c9ed9d7);
#
#
#
#         marker_4bb8eb1098d870bf4972bf8a39a3585c.bindPopup(popup_666b91825097a1d6c5855878b0a75c68)
#         ;
#
#
#
#
#             var marker_a1aa57af747cf19767c530699b4e8d39 = L.marker(
#                 [37.765158, -122.404234],
#                 {}
#             ).addTo(map_335802e04213b24ea102e5d2ffb8c741);
#
#
#             var icon_26c15c6c2a2f8eb82cf3378b0f7d62c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a1aa57af747cf19767c530699b4e8d39.setIcon(icon_26c15c6c2a2f8eb82cf3378b0f7d62c4);
#
#
#         var popup_1d62d5ced47aed6ebfc58a7ac3fdaeba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adb37fa8a4ed54259378a158c455e49c = $(`&lt;div id=&quot;html_adb37fa8a4ed54259378a158c455e49c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Company Location&lt;/div&gt;`)[0];
#                 popup_1d62d5ced47aed6ebfc58a7ac3fdaeba.setContent(html_adb37fa8a4ed54259378a158c455e49c);
#
#
#
#         marker_a1aa57af747cf19767c530699b4e8d39.bindPopup(popup_1d62d5ced47aed6ebfc58a7ac3fdaeba)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# checking the location from the closest airport from San Fracisco - USA

latitude = 37.765158
longitude = -122.404234

geolocator = Nominatim(user_agent="airport_finder")
airport_coordinates = (37.6213129, -122.3811443)  # San Francisco International Airport (SFO)
distance = geodesic((latitude, longitude), airport_coordinates).miles
print(f"The closest airport is San Francisco International Airport (SFO), which is approximately {distance:.2f} miles away.")
# Out:
# The closest airport is San Francisco International Airport (SFO), which is approximately 10.00 miles away.

# %% [markdown]
# ### Getting nearby venues through Foursquare for Los Angeles ###

# %%
where_2 = "Los Angeles, USA"
latitude2 = 34.031276
longitude2 = -118.456806

# %%
# locating a random company in Los Angeles from the game and number of employees criteria
latitude2 = 34.031276
longitude2 = -118.456806

m = folium.Map(location=[latitude2, longitude2], zoom_start=10)

icon = folium.Icon(icon="cloud")
folium.Marker([latitude2, longitude2], popup="Your Location", icon=icon).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38b2c020bc475d2a5bec6a1f2803c6b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38b2c020bc475d2a5bec6a1f2803c6b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38b2c020bc475d2a5bec6a1f2803c6b7 = L.map(
#                 &quot;map_38b2c020bc475d2a5bec6a1f2803c6b7&quot;,
#                 {
#                     center: [34.031276, -118.456806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c19377a3ad88f559002ef1427cf824 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38b2c020bc475d2a5bec6a1f2803c6b7);
#
#
#             var marker_841a289d42751485c93c6610f3ba9f23 = L.marker(
#                 [34.031276, -118.456806],
#                 {}
#             ).addTo(map_38b2c020bc475d2a5bec6a1f2803c6b7);
#
#
#             var icon_daf914b2cf15a6a3ce1c6cbee83b8b52 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_841a289d42751485c93c6610f3ba9f23.setIcon(icon_daf914b2cf15a6a3ce1c6cbee83b8b52);
#
#
#         var popup_54a865088c5a1740aa305a9807b68b96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fc8b270479415aa4a4fd15f2b51537f = $(`&lt;div id=&quot;html_3fc8b270479415aa4a4fd15f2b51537f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Your Location&lt;/div&gt;`)[0];
#                 popup_54a865088c5a1740aa305a9807b68b96.setContent(html_3fc8b270479415aa4a4fd15f2b51537f);
#
#
#
#         marker_841a289d42751485c93c6610f3ba9f23.bindPopup(popup_54a865088c5a1740aa305a9807b68b96)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# checking for close Child School

def requests_for_foursquare (query, lat, lon, radius=1000, limit=1):
    lat = 34.031276
    lon = -118.456806 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
child_school_la = requests_for_foursquare ("Preschool", lat, lon, radius=1000, limit=5)
child_school_la
# Out:
# {'results': [{'fsq_id': '8f15b629dbf247579e380e28',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 597,
#    'geocodes': {'drop_off': {'latitude': 34.036799, 'longitude': -118.457263},
#     'main': {'latitude': 34.036621, 'longitude': -118.457464},
#     'roof': {'latitude': 34.036621, 'longitude': -118.457464}},
#    'link': '/v3/places/8f15b629dbf247579e380e28',
#    'location': {'address': '1815 Brockton Ave',
#     'census_block': '060372676003002',
#     'country': 'US',
#     'dma': 'Los Angeles',
#     'formatted_address': '1815 Brockton Ave, Los Angeles, CA 90025',
#     'locality': 'Los Angeles',
#     'postcode': '90025',
#     'region': 'CA'},
#    'name': 'Our World Preschool',
#    'related_places': {}},
#   {'fsq_id': '4bc3d115b492d13a1a5ca960',
#    'categories': [{'id': 11025,
#      'name': 'Child Care Service',
#      'short_name': 'Child Care',
#      'plural_name': 'Child Care Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#       'suffix': '.png'}},
#     {'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 744,
#    'geocodes': {'main': {'latitude': 34.030477, 'longitude': -118.448647},
#     'roof': {'latitude': 34.030477, 'longitude': -118.448647}},
#    'link': '/v3/places/4bc3d115b492d13a1a5ca960',
#    'location': {'address': '11827 W Pico Blvd',
#     'census_block': '060372676002021',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Los Angeles',
#     'formatted_address': '11827 W Pico Blvd, Los Angeles, CA 90064',
#     'locality': 'Los Angeles',
#     'postcode': '90064',
#     'region': 'CA'},
#    'name': 'Little Village Nursery School',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': 'a678ad14432b44729a3f6b09',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 659,
#    'geocodes': {'drop_off': {'latitude': 34.03674, 'longitude': -118.454586},
#     'main': {'latitude': 34.036955, 'longitude': -118.454715},
#     'roof': {'latitude': 34.036955, 'longitude': -118.454715}},
#    'link': '/v3/places/a678ad14432b44729a3f6b09',
#    'location': {'address': '11851 Missouri Ave',
#     'address_extended': 'Ste 1',
#     'census_block': '060372676003000',
#     'country': 'US',
#     'dma': 'Los Angeles',
#     'formatted_address': '11851 Missouri Ave, Los Angeles, CA 90025',
#     'locality': 'Los Angeles',
#     'postcode': '90025',
#     'region': 'CA'},
#    'name': 'Mindful Heart Kids',
#    'related_places': {}},
#   {'fsq_id': '69080e42811442e26377c126',
#    'categories': [{'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 772,
#    'geocodes': {'drop_off': {'latitude': 34.030156, 'longitude': -118.448657},
#     'main': {'latitude': 34.029973, 'longitude': -118.448566},
#     'roof': {'latitude': 34.029973, 'longitude': -118.448566}},
#    'link': '/v3/places/69080e42811442e26377c126',
#    'location': {'address': '11916 W Pico Blvd',
#     'census_block': '060372712002009',
#     'country': 'US',
#     'dma': 'Los Angeles',
#     'formatted_address': '11916 W Pico Blvd, Los Angeles, CA 90064',
#     'locality': 'Los Angeles',
#     'postcode': '90064',
#     'region': 'CA'},
#    'name': 'Maple Tree',
#    'related_places': {}},
#   {'fsq_id': '17d19933e9804479232d099f',
#    'categories': [{'id': 11025,
#      'name': 'Child Care Service',
#      'short_name': 'Child Care',
#      'plural_name': 'Child Care Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/daycare_',
#       'suffix': '.png'}},
#     {'id': 12056,
#      'name': 'Preschool',
#      'short_name': 'Preschool',
#      'plural_name': 'Preschools',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 876,
#    'geocodes': {'drop_off': {'latitude': 34.031825, 'longitude': -118.447261},
#     'main': {'latitude': 34.032045, 'longitude': -118.447335},
#     'roof': {'latitude': 34.032045, 'longitude': -118.447335}},
#    'link': '/v3/places/17d19933e9804479232d099f',
#    'location': {'address': '11733 Tennessee Ave',
#     'census_block': '060372676002019',
#     'country': 'US',
#     'dma': 'Los Angeles',
#     'formatted_address': '11733 Tennessee Ave, Los Angeles, CA 90064',
#     'locality': 'Los Angeles',
#     'postcode': '90064',
#     'region': 'CA'},
#    'name': 'Sunny Childcare Preschool',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 34.031276,
#      'longitude': -118.456806},
#     'radius': 1000}}}}

# %%
near_child_school_la = []
for venue in child_school_la["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    near_child_school_la.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

child_school_df2 = pd.DataFrame(near_child_school_la)

child_school_df2
# Out:
#                             Name   Latitude   Longitude  Distance
# 0            Our World Preschool  34.036621 -118.457464       597
# 1  Little Village Nursery School  34.030477 -118.448647       744
# 2             Mindful Heart Kids  34.036955 -118.454715       659
# 3                     Maple Tree  34.029973 -118.448566       772
# 4      Sunny Childcare Preschool  34.032045 -118.447335       876

# %%
# Creating a map centered around a location of child school 
m = folium.Map(location=[child_school_df2.iloc[0]['Latitude'], child_school_df2.iloc[0]['Longitude']], zoom_start=12)

for index, row in child_school_df2.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [34.031276, -118.456806]
folium.Marker(company_location, 
              tooltip='hulu',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba2a1c565e2c8880a378d20eb1a3d61a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba2a1c565e2c8880a378d20eb1a3d61a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba2a1c565e2c8880a378d20eb1a3d61a = L.map(
#                 &quot;map_ba2a1c565e2c8880a378d20eb1a3d61a&quot;,
#                 {
#                     center: [34.036621, -118.457464],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf4c2d36ae68a9c22429898c394d5d47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba2a1c565e2c8880a378d20eb1a3d61a);
#
#
#             var marker_2959175c97b15c9f358c17f3e99a3ca5 = L.marker(
#                 [34.036621, -118.457464],
#                 {}
#             ).addTo(map_ba2a1c565e2c8880a378d20eb1a3d61a);
#
#
#             var icon_2385a49b482074f7db06bab96371901b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2959175c97b15c9f358c17f3e99a3ca5.setIcon(icon_2385a49b482074f7db06bab96371901b);
#
#
#             marker_2959175c97b15c9f358c17f3e99a3ca5.bindTooltip(
#                 `&lt;div&gt;
#                      Our World Preschool
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4bc7f19543026bd594a89dab2a1c53b2 = L.marker(
#                 [34.030477, -118.448647],
#                 {}
#             ).addTo(map_ba2a1c565e2c8880a378d20eb1a3d61a);
#
#
#             var icon_5e029ee217f7ab659020fd2a05cf7617 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4bc7f19543026bd594a89dab2a1c53b2.setIcon(icon_5e029ee217f7ab659020fd2a05cf7617);
#
#
#             marker_4bc7f19543026bd594a89dab2a1c53b2.bindTooltip(
#                 `&lt;div&gt;
#                      Little Village Nursery School
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_13f7955b07ced972c718f9aae02b00a9 = L.marker(
#                 [34.036955, -118.454715],
#                 {}
#             ).addTo(map_ba2a1c565e2c8880a378d20eb1a3d61a);
#
#
#             var icon_1a539eb44805b7fb93e1c4c331a0f5a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13f7955b07ced972c718f9aae02b00a9.setIcon(icon_1a539eb44805b7fb93e1c4c331a0f5a7);
#
#
#             marker_13f7955b07ced972c718f9aae02b00a9.bindTooltip(
#                 `&lt;div&gt;
#                      Mindful Heart Kids
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_465c587c555eb660e14a24ad989440c2 = L.marker(
#                 [34.029973, -118.448566],
#                 {}
#             ).addTo(map_ba2a1c565e2c8880a378d20eb1a3d61a);
#
#
#             var icon_b686fff42e9624ecd97fb67849dcbfff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_465c587c555eb660e14a24ad989440c2.setIcon(icon_b686fff42e9624ecd97fb67849dcbfff);
#
#
#             marker_465c587c555eb660e14a24ad989440c2.bindTooltip(
#                 `&lt;div&gt;
#                      Maple Tree
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_16b679af41c862390ca24746441e6920 = L.marker(
#                 [34.032045, -118.447335],
#                 {}
#             ).addTo(map_ba2a1c565e2c8880a378d20eb1a3d61a);
#
#
#             var icon_ce6e2e5bf27535ed4ee1b43f395bfee5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %%
# checking for close Starbucks

def requests_for_foursquare (query, lat, lon, radius=2000, limit=1):
    lat = 34.031276 
    lon = -118.456806 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
starbucks_la = requests_for_foursquare ("Starbucks", lat, lon, radius=1000, limit=5)
starbucks_la
# Out:
# {'results': [{'fsq_id': '570eae75498e636a8f86a3c8',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 859,
#    'geocodes': {'main': {'latitude': 34.024394, 'longitude': -118.460891},
#     'roof': {'latitude': 34.024394, 'longitude': -118.460891}},
#    'link': '/v3/places/570eae75498e636a8f86a3c8',
#    'location': {'address': '2727 Pico Blvd',
#     'census_block': '060377018013009',
#     'country': 'US',
#     'cross_street': 'Stewart',
#     'dma': 'Los Angeles',
#     'formatted_address': '2727 Pico Blvd (Stewart), Santa Monica, CA 90405',
#     'locality': 'Santa Monica',
#     'postcode': '90405',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '5206b3fb11d29e51de098edc',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 812,
#    'geocodes': {'main': {'latitude': 34.034989, 'longitude': -118.449162},
#     'roof': {'latitude': 34.034989, 'longitude': -118.449162}},
#    'link': '/v3/places/5206b3fb11d29e51de098edc',
#    'location': {'address': '11727 W Olympic Blvd',
#     'census_block': '060372676002007',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Los Angeles',
#     'formatted_address': '11727 W Olympic Blvd, Los Angeles, CA 90064',
#     'locality': 'Los Angeles',
#     'postcode': '90064',
#     'region': 'CA'},
#    'name': 'Starbucks',
#    'related_places': {'parent': {'fsq_id': '4a6a6435f964a52054cd1fe3',
#      'categories': [{'id': 17069,
#        'name': 'Grocery Store',
#        'short_name': 'Grocery Store',
#        'plural_name': 'Grocery Stores',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#         'suffix': '.png'}}],
#      'name': 'Ralphs'}},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 34.031276,
#      'longitude': -118.456806},
#     'radius': 1000}}}}

# %%
near_starbucks_la = []
for venue in starbucks_la["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    near_starbucks_la.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

starbucks_df_la = pd.DataFrame(near_starbucks_la)

starbucks_df_la
# Out:
#         Name   Latitude   Longitude  Distance
# 0  Starbucks  34.024394 -118.460891       859
# 1  Starbucks  34.034989 -118.449162       812

# %%
# Creating a map centered around a location of Starbucks
m = folium.Map(location=[starbucks_df_la.iloc[0]['Latitude'], starbucks_df_la.iloc[0]['Longitude']], zoom_start=12)

for index, row in starbucks_df_la.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [34.031276, -118.456806]
folium.Marker(company_location, 
              tooltip='hulu',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdd3ce1a745c3d422582e49cb889c7a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdd3ce1a745c3d422582e49cb889c7a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdd3ce1a745c3d422582e49cb889c7a5 = L.map(
#                 &quot;map_bdd3ce1a745c3d422582e49cb889c7a5&quot;,
#                 {
#                     center: [34.024394, -118.460891],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e81af170ac3744784558471e9613c00 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bdd3ce1a745c3d422582e49cb889c7a5);
#
#
#             var marker_1535aba0e55d29c84c9a7526cad79722 = L.marker(
#                 [34.024394, -118.460891],
#                 {}
#             ).addTo(map_bdd3ce1a745c3d422582e49cb889c7a5);
#
#
#             var icon_a054a58cc38542804aac15c2c49c0fc5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1535aba0e55d29c84c9a7526cad79722.setIcon(icon_a054a58cc38542804aac15c2c49c0fc5);
#
#
#             marker_1535aba0e55d29c84c9a7526cad79722.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a50430efef78ad5c84d15e4055cd1c51 = L.marker(
#                 [34.034989, -118.449162],
#                 {}
#             ).addTo(map_bdd3ce1a745c3d422582e49cb889c7a5);
#
#
#             var icon_3a88e23bda574e9c8fb458c247f13bfd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a50430efef78ad5c84d15e4055cd1c51.setIcon(icon_3a88e23bda574e9c8fb458c247f13bfd);
#
#
#             marker_a50430efef78ad5c84d15e4055cd1c51.bindTooltip(
#                 `&lt;div&gt;
#                      Starbucks
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8d4ac03f88c8808a363561f60c9fb17b = L.marker(
#                 [34.031276, -118.456806],
#                 {}
#             ).addTo(map_bdd3ce1a745c3d422582e49cb889c7a5);
#
#
#             var icon_2b0e05f9fe74bbcf7586b1335bd285ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d4ac03f88c8808a363561f60c9fb17b.setIcon(icon_2b0e05f9fe74bbcf7586b1335bd285ba);
#
#
#             marker_8d4ac03f88c8808a363561f60c9fb17b.bindTooltip(
#                 `&lt;div&gt;
#                      hulu
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# checking for close Vegan Restaurants

def requests_for_foursquare (query, lat, lon, radius=1000, limit=1):
    lat = 34.031276 
    lon = -118.456806  
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
vegan_restaurant_la = requests_for_foursquare ("Vegan", lat, lon, radius=1000, limit=5)
vegan_restaurant_la
# Out:
# {'results': [{'fsq_id': '56fea33a498e4c6f24e1bf4b',
#    'categories': [{'id': 13028,
#      'name': 'Breakfast Spot',
#      'short_name': 'Breakfast',
#      'plural_name': 'Breakfast Spots',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 549,
#    'geocodes': {'main': {'latitude': 34.03133, 'longitude': -118.462657},
#     'roof': {'latitude': 34.03133, 'longitude': -118.462657}},
#    'link': '/v3/places/56fea33a498e4c6f24e1bf4b',
#    'location': {'address': '1814 Berkeley St',
#     'census_block': '060377018011019',
#     'country': 'US',
#     'cross_street': 'Nebraska',
#     'dma': 'Los Angeles',
#     'formatted_address': '1814 Berkeley St (Nebraska), Santa Monica, CA 90404',
#     'locality': 'Santa Monica',
#     'postcode': '90404',
#     'region': 'CA'},
#    'name': 'Bondi Harvest',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4a8875b7f964a520830620e3',
#    'categories': [{'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [{'id': '6adf56af-558f-4fc8-8bb0-bfb35dd622bc',
#      'name': "Trader Joe's"}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 556,
#    'geocodes': {'main': {'latitude': 34.026369, 'longitude': -118.455772},
#     'roof': {'latitude': 34.026369, 'longitude': -118.455772}},
#    'link': '/v3/places/4a8875b7f964a520830620e3',
#    'location': {'address': '3212 Pico Blvd',
#     'census_block': '060377023001003',
#     'country': 'US',
#     'cross_street': 'at 32nd St',
#     'dma': 'Los Angeles',
#     'formatted_address': '3212 Pico Blvd (at 32nd St), Santa Monica, CA 90405',
#     'locality': 'Santa Monica',
#     'postcode': '90405',
#     'region': 'CA'},
#    'name': "Trader Joe's",
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4c36293a93db0f47a3991d92',
#    'categories': [{'id': 13287,
#      'name': 'Kosher Restaurant',
#      'short_name': 'Kosher',
#      'plural_name': 'Kosher Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13302,
#      'name': 'Mediterranean Restaurant',
#      'short_name': 'Mediterranean',
#      'plural_name': 'Mediterranean Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#       'suffix': '.png'}},
#     {'id': 13309,
#      'name': 'Middle Eastern Restaurant',
#      'short_name': 'Middle Eastern',
#      'plural_name': 'Middle Eastern Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 722,
#    'geocodes': {'main': {'latitude': 34.030399, 'longitude': -118.448928},
#     'roof': {'latitude': 34.030399, 'longitude': -118.448928}},
#    'link': '/v3/places/4c36293a93db0f47a3991d92',
#    'location': {'address': '11921 W Pico Blvd',
#     'census_block': '060372676002021',
#     'country': 'US',
#     'cross_street': 'at Westgate Ave',
#     'dma': 'Los Angeles',
#     'formatted_address': '11921 W Pico Blvd (at Westgate Ave), Los Angeles, CA 90064',
#     'locality': 'Los Angeles',
#     'postcode': '90064',
#     'region': 'CA'},
#    'name': 'Habayit',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '549f71ee498ebc7d8cafb8bc',
#    'categories': [{'id': 13379,
#      'name': 'Vietnamese Restaurant',
#      'short_name': 'Vietnamese',
#      'plural_name': 'Vietnamese Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 514,
#    'geocodes': {'drop_off': {'latitude': 34.026517, 'longitude': -118.456116},
#     'main': {'latitude': 34.026691, 'longitude': -118.456203},
#     'roof': {'latitude': 34.026691, 'longitude': -118.456203}},
#    'link': '/v3/places/549f71ee498ebc7d8cafb8bc',
#    'location': {'address': '3221 Pico Blvd',
#     'census_block': '060377018013016',
#     'country': 'US',
#     'cross_street': '33rd',
#     'dma': 'Los Angeles',
#     'formatted_address': '3221 Pico Blvd (33rd), Santa Monica, CA 90405',
#     'locality': 'Santa Monica',
#     'postcode': '90405',
#     'region': 'CA'},
#    'name': 'Viet Noodle Bar',
#    'related_places': {},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '86a698df5358215cfa4e32d4',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13377,
#      'name': 'Vegan and Vegetarian Restaurant',
#      'short_name': 'Vegan and Vegetarian Restaurant',
#      'plural_name': 'Vegan and Vegetarian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'e9b6ff79-62b5-4a0b-9ef6-b9bf15f3b53f',
#      'name': 'Sweetgreen'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 435,
#    'geocodes': {'main': {'latitude': 34.034839, 'longitude': -118.458764}},
#    'link': '/v3/places/86a698df5358215cfa4e32d4',
#    'location': {'address': '12210 Nebraska Ave',
#     'census_block': '060372676003007',
#     'country': 'US',
#     'dma': 'Los Angeles',
#     'formatted_address': '12210 Nebraska Ave, Los Angeles, CA 90025',
#     'locality': 'Los Angeles',
#     'postcode': '90025',
#     'region': 'CA'},
#    'name': 'Sweetgreen',
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 34.031276,
#      'longitude': -118.456806},
#     'radius': 1000}}}}

# %%
vegan_la = []
for venue in vegan_restaurant_la["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    vegan_la.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

vegan_restaurant_df_la = pd.DataFrame(vegan_la)

vegan_restaurant_df_la
# Out:
#               Name   Latitude   Longitude  Distance
# 0    Bondi Harvest  34.031330 -118.462657       549
# 1     Trader Joe's  34.026369 -118.455772       556
# 2          Habayit  34.030399 -118.448928       722
# 3  Viet Noodle Bar  34.026691 -118.456203       514
# 4       Sweetgreen  34.034839 -118.458764       435

# %%
# Creating a map centered around a location of vegan restaurant
m = folium.Map(location=[vegan_restaurant_df_la.iloc[0]['Latitude'], vegan_restaurant_df_la.iloc[0]['Longitude']], zoom_start=12)

for index, row in vegan_restaurant_df_la.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [34.031276, -118.456806]
folium.Marker(company_location, 
              tooltip='hulu',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0478f96a6cce93cf42ebefddc259cb2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0478f96a6cce93cf42ebefddc259cb2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0478f96a6cce93cf42ebefddc259cb2a = L.map(
#                 &quot;map_0478f96a6cce93cf42ebefddc259cb2a&quot;,
#                 {
#                     center: [34.03133, -118.462657],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b1fc3655277661b5840c8eb547ae986 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0478f96a6cce93cf42ebefddc259cb2a);
#
#
#             var marker_50c3db4af40fc8f60df4b1106951dcb1 = L.marker(
#                 [34.03133, -118.462657],
#                 {}
#             ).addTo(map_0478f96a6cce93cf42ebefddc259cb2a);
#
#
#             var icon_46dd8bb577fade86eaa7d21199b4f79e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_50c3db4af40fc8f60df4b1106951dcb1.setIcon(icon_46dd8bb577fade86eaa7d21199b4f79e);
#
#
#             marker_50c3db4af40fc8f60df4b1106951dcb1.bindTooltip(
#                 `&lt;div&gt;
#                      Bondi Harvest
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_066b9e912164cbedae10a9b6d4963845 = L.marker(
#                 [34.026369, -118.455772],
#                 {}
#             ).addTo(map_0478f96a6cce93cf42ebefddc259cb2a);
#
#
#             var icon_e4124b0bf57da8b79a27c0290d327172 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_066b9e912164cbedae10a9b6d4963845.setIcon(icon_e4124b0bf57da8b79a27c0290d327172);
#
#
#             marker_066b9e912164cbedae10a9b6d4963845.bindTooltip(
#                 `&lt;div&gt;
#                      Trader Joe&#x27;s
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_35f1701bb7498af38657291f0c30fcac = L.marker(
#                 [34.030399, -118.448928],
#                 {}
#             ).addTo(map_0478f96a6cce93cf42ebefddc259cb2a);
#
#
#             var icon_b13909047840ee691ef320fc13b5e9e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_35f1701bb7498af38657291f0c30fcac.setIcon(icon_b13909047840ee691ef320fc13b5e9e5);
#
#
#             marker_35f1701bb7498af38657291f0c30fcac.bindTooltip(
#                 `&lt;div&gt;
#                      Habayit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ea244953462eb6d2358e1e3a10bb4f00 = L.marker(
#                 [34.026691, -118.456203],
#                 {}
#             ).addTo(map_0478f96a6cce93cf42ebefddc259cb2a);
#
#
#             var icon_1b4e25002ac9b74414c242a923ecba1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea244953462eb6d2358e1e3a10bb4f00.setIcon(icon_1b4e25002ac9b74414c242a923ecba1f);
#
#
#             marker_ea244953462eb6d2358e1e3a10bb4f00.bindTooltip(
#                 `&lt;div&gt;
#                      Viet Noodle Bar
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6330571e2baf994560eb0fdee541902f = L.marker(
#                 [34.034839, -118.458764],
#                 {}
#             ).addTo(map_0478f96a6cce93cf42ebefddc259cb2a);
#
#
#             var icon_05461d4bc84a24ce2d80487a4b8684ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6330571

# %%
# checking for close Airport 

def requests_for_foursquare (query, lat, lon, radius=500, limit=1):
    lat = 34.031276
    lon = -118.456806 
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lat}%2C{lon}&radius={radius}&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }
    
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")

# %%
airport_la = requests_for_foursquare ("International Airport", lat, lon, radius=50000, limit=5)
airport_la
# Out:
# {'results': [{'fsq_id': '439ec330f964a520102c1fe3',
#    'categories': [{'id': 19031,
#      'name': 'Airport',
#      'short_name': 'Airport',
#      'plural_name': 'Airports',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 10798,
#    'geocodes': {'main': {'latitude': 33.94352, 'longitude': -118.40842},
#     'roof': {'latitude': 33.944697, 'longitude': -118.398107}},
#    'link': '/v3/places/439ec330f964a520102c1fe3',
#    'location': {'address': '1 World Way',
#     'census_block': '060379800281018',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'Los Angeles',
#     'formatted_address': '1 World Way, Los Angeles, CA 90045',
#     'locality': 'Los Angeles',
#     'po_box': 'P.O. Box 92216',
#     'postcode': '90045',
#     'region': 'CA'},
#    'name': 'Los Angeles International Airport (LAX)',
#    'related_places': {'children': [{'fsq_id': '4f17cbabe4b0f1e7bab9e1c3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'P-1 Parking'},
#      {'fsq_id': '53eec3e9498e08d769c158d3',
#       'categories': [{'id': 16046,
#         'name': 'Scenic Lookout',
#         'short_name': 'Scenic Lookout',
#         'plural_name': 'Scenic Lookouts',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#          'suffix': '.png'}}],
#       'name': 'LAX Landing Viewpoint'},
#      {'fsq_id': '58dea5385a58691421ab2d08',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 06R - 24L'},
#      {'fsq_id': '4ed698068b81665993cab175',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'P-5 Parking'},
#      {'fsq_id': '4fbd79d2e4b0571877b0f819',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 7L - 25R'},
#      {'fsq_id': '531bc68a498ea588779d0be0',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'P-6 Parking'},
#      {'fsq_id': '4bbc17baafe1b713a518304b',
#       'categories': [{'id': 16026,
#         'name': 'Monument',
#         'short_name': 'Monument',
#         'plural_name': 'Monuments',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#          'suffix': '.png'}}],
#       'name': 'LAX Sign'},
#      {'fsq_id': '583282457ff1e43c19279fe8',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 6L - 24R'},
#      {'fsq_id': '4c2273b29085d13afc5a86cc',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Atlantic Aviation'},
#      {'fsq_id': '4be2b7d3f07b0f476bfbf543',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 6'},
#      {'fsq_id': '507b3767e4b00277f435bd70',
#       'categories': [{'id': 16047,
#         'name': 'Sculpture Garden',
#         'short_name': 'Sculpture',
#         'plural_name': 'Sculpture Gardens',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#          'suffix': '.png'}}],
#       'name': 'Lax Pylons'},
#      {'fsq_id': '4b8fd6cef964a520d26433e3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Economy Public Parking Lot C'},
#      {'fsq_id': '4d95f7de942ba093895d478c',
#       'categories': [{'id': 11130,
#         'name': 'Office Building',
#         'short_name': 'Office Building',
#         'plural_name': 'Office Buildings',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'}}],
#       'name': 'LAX Control Tower'},
#      {'fsq_id': '4bdae1e763c5c9b6974e2568',
#       'categories': [{'id': 11028,
#         'name': 'Construction',
#         'short_name': 'Construction',
#         'plural_name': 'Construction',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 4'},
#      {'fsq_id': '4bdf4fc70ee3a593e2bd33b0',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 1'},
#      {'fsq_id': '567f105f498e9310687eb2e7',
#       'categories': [{'id': 19031,
#         'name': 'Airport',
#         'short_name': 'Airport',
#         'plural_name': 'Airports',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'reLAX Lounge'},
#      {'fsq_id': '4ca02c008afca0939eb51016',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'LAX Economy Lot E'},
#      {'fsq_id': '4e73e4b8b61c22c6377c9555',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'P-4 Parking'},
#      {'fsq_id': '4bea177d62c0c9286088e0d4',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Tom Bradley International Terminal'},
#      {'fsq_id': '6260f1de80170c470b508399',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 3'},
#      {'fsq_id': '4bee7a60d1b7d13a8413cdec',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 8'},
#      {'fsq_id': '4bd0a7b0046076b0e56b7071',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 2'},
#      {'fsq_id': '4dd01ebf1f6eb12270a46adf',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'LAX Cell Phone Waiting Lot'},
#      {'fsq_id': '4db7327fced7dba4f02deec7',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'American Eagle Remote Terminal'},
#      {'fsq_id': '4c0d6675336220a11aaaca77',
#       'categories': [{'id': 12086,
#         'name': 'Non-Profit Organization',
#         'short_name': 'Non-Profit Organization',
#         'plural_name': 'Non-Profit Organizations',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'}}],
#       'name': 'Bob Hope Hollywood Uso At Lax'},
#      {'fsq_id': '5db88a4c6eac3900086c1a9b',
#       'categories': [{'id': 19049,
#         'name': 'Taxi Stand',
#         'short_name': 'Taxi Stand',
#         'plural_name': 'Taxi Stands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/taxi_',
#          'suffix': '.png'}}],
#       'name': 'LAX-it'},
#      {'fsq_id': '4bded7690ee3a593a30432b0',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 5'},
#      {'fsq_id': '4eb46ff7469073bbc5b927a5',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'P-2 Parking'},
#      {'fsq_id': '4bd1311ba8b3a5930a79655f',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 7'},
#      {'fsq_id': '4b75d646f964a5204c282ee3',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': "Park 'N Fly"},
#      {'fsq_id': '4d37edce3ffba14391355756',
#       'categories': [{'id': 11031,
#         'name': 'Distribution Center',
#         'short_name': 'Distributor',
#         'plural_name': 'Distribution Centers',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#          'suffix': '.png'}}],
#       'name': 'Imperial Cargo Complex'},
#      {'fsq_id': '4b8b5a92f964a520399d32e3',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Official Jetblue Terminal 3 - Los Angeles International Airport'},
#      {'fsq_id': '4ea86ecd9adf64e06bf4d1a0',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'New South Parking'},
#      {'fsq_id': '60d1ebb1811078544e784195',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Terminal 1.5'},
#      {'fsq_id': '4ccdcec6ee23a143af3428a8',
#       'categories': [{'id': 16026,
#         'name': 'Monument',
#         'short_name': 'Monument',
#         'plural_name': 'Monuments',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#          'suffix': '.png'}}],
#       'name': 'Theme Building'},
#      {'fsq_id': '4e04cec7aeb771d978820434',
#       'categories': [{'id': 19006,
#         'name': 'Electric Vehicle Charging Station',
#         'short_name': 'Electric Vehicle Charging Station',
#         'plural_name': 'Electric Vehicle Charging Stations',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#          'suffix': '.png'}}],
#       'name': 'Electric Vehicle Charging Stations'},
#      {'fsq_id': '4e212ca9483b041af1ea9a54',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'P-3 Parking'},
#      {'fsq_id': '620960d7f8f89122cb0eec6a',
#       'categories': [{'id': 16026,
#         'name': 'Monument',
#         'short_name': 'Monument',
#         'plural_name': 'Monuments',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#          'suffix': '.png'}}],
#       'name': 'LAX Sign at Lincoln'},
#      {'fsq_id': '516c6b9f498e44df7fd96038',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Runway 7R - 25L'},
#      {'fsq_id': '50bd2e15e4b0132868ae818b',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Parking P2b'},
#      {'fsq_id': '4dc372bdc65b89d3ca3c78c2',
#       'categories': [{'id': 19020,
#         'name': 'Parking',
#         'short_name': 'Parking',
#         'plural_name': 'Parking',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#          'suffix': '.png'}}],
#       'name': 'Employee Parking Lot E'}]},
#    'timezone': 'America/Los_Angeles'},
#   {'fsq_id': '4bea177d62c0c9286088e0d4',
#    'categories': [{'id': 19037,
#      'name': 'Airport Terminal',
#      'short_name': 'Terminal',
#      'plural_name': 'Airport Terminals',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 10686,
#    'geocodes': {'main': {'latitude': 33.94352, 'longitude': -118.408537},
#     'roof': {'latitude': 33.94352, 'longitude': -118.408537}},
#    'link': '/v3/places/4bea177d62c0c9286088e0d4',
#    'location': {'address': '380 World Way',
#     'census_block': '060379800281018',
#     'country': 'US',
#     'dma': 'Los Angeles',
#     'formatted_address': '380 World Way, Los Angeles, CA 90045',
#     'locality': 'Los Angeles',
#     'postcode': '90045',
#     'region': 'CA'},
#    'name': 'Tom Bradley International Terminal (TBIT)',
#    'related_places': {'parent': {'fsq_id': '439ec330f964a520102c1fe3',
#      'categories': [{'id': 19031,
#        'name': 'Airport',
#        'short_name': 'Airport',
#        'plural_name': 'Airports',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#         'suffix': '.png'}}],
#      'name': 'Los Angeles International Airport (LAX)'},
#     'children': [{'fsq_id': '5cc1025d81635b002c71dc44',
#       'categories': [{'id': 17100,
#         'name': 'Newsstand',
#         'short_name': 'Newsstand',
#         'plural_name': 'Newsstands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#          'suffix': '.png'}}],
#       'name': 'Paradies Lagardère'},
#      {'fsq_id': '4e077631fa767637fd2b1539',
#       'categories': [{'id': 17036,
#         'name': 'Duty-free Store',
#         'short_name': 'Duty-free',
#         'plural_name': 'Duty-free Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#          'suffix': '.png'}}],
#       'name': 'Duty Free'},
#      {'fsq_id': '54dfcfb3498eff11e3479d94',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Emirates Airlines'},
#      {'fsq_id': '522f870711d25ac8e5811cc0',
#       'categories': [{'id': 17043,
#         'name': 'Clothing Store',
#         'short_name': 'Apparel',
#         'plural_name': 'Clothing Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#          'suffix': '.png'}},
#        {'id': 17044,
#         'name': 'Fashion Accessories Store',
#         'short_name': 'Fashion Accessories Store',
#         'plural_name': 'Fashion Accessories Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#          'suffix': '.png'}}],
#       'name': 'Porsche Design at TBIT'},
#      {'fsq_id': '5a4edfda772fbc5eb801d7d3',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'XiamenAir'},
#      {'fsq_id': '4dd4c7be52b18e28aa1cf586',
#       'categories': [{'id': 19039,
#         'name': 'Baggage Claim',
#         'short_name': 'Baggage Claim',
#         'plural_name': 'Baggage Claims',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#          'suffix': '.png'}}],
#       'name': 'Baggage Claim - TBIT'},
#      {'fsq_id': '5c439d33625a66002c0c7aa8',
#       'categories': [{'id': 17043,
#         'name': 'Clothing Store',
#         'short_name': 'Apparel',
#         'plural_name': 'Clothing Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#          'suffix': '.png'}}],
#       'name': 'Emporio Armani'},
#      {'fsq_id': '562af5ff498e45f3e1685ade',
#       'categories': [{'id': 12064,
#         'name': 'Government Building',
#         'short_name': 'Government',
#         'plural_name': 'Government Buildings',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#          'suffix': '.png'}}],
#       'name': 'LAX Immigration'},
#      {'fsq_id': '4fb5e858e4b0ec527a6cacd5',
#       'categories': [{'id': 19031,
#         'name': 'Airport',
#         'short_name': 'Airport',
#         'plural_name': 'Airports',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': "Korean Airlines' Business Class Lounge"},
#      {'fsq_id': '5328a61e498e49e0925c9fa0',
#       'categories': [{'id': 17100,
#         'name': 'Newsstand',
#         'short_name': 'Newsstand',
#         'plural_name': 'Newsstands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#          'suffix': '.png'}}],
#       'name': 'CNN News Stand'},
#      {'fsq_id': '522f861911d2b087f8b24e4e',
#       'categories': [{'id': 17045,
#         'name': 'Jewelry Store',
#         'short_name': 'Jewelry',
#         'plural_name': 'Jewelry Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#          'suffix': '.png'}}],
#       'name': 'BVLGARI'},
#      {'fsq_id': '522f87aa11d25e589b081377',
#       'categories': [{'id': 17094,
#         'name': 'Luggage Store',
#         'short_name': 'Luggage Store',
#         'plural_name': 'Luggage Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#          'suffix': '.png'}}],
#       'name': 'Tumi'},
#      {'fsq_id': '579953e6498e2fd169f2a98e',
#       'categories': [{'id': 17043,
#         'name': 'Clothing Store',
#         'short_name': 'Apparel',
#         'plural_name': 'Clothing Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#          'suffix': '.png'}},
#        {'id': 17044,
#         'name': 'Fashion Accessories Store',
#         'short_name': 'Fashion Accessories Store',
#         'plural_name': 'Fashion Accessories Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#          'suffix': '.png'}},
#        {'id': 17048,
#         'name': 'Shoe Store',
#         'short_name': 'Shoes',
#         'plural_name': 'Shoe Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#          'suffix': '.png'}}],
#       'name': 'Salvatore Ferragamo'},
#      {'fsq_id': '50df27fde4b0f2167321e41d',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'Star Alliance First Class Lounge'},
#      {'fsq_id': '4ce8adee595cb1f744a7ca14',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'Los Angeles International Lounge'},
#      {'fsq_id': '4e750567d4c0934471b475c3',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Air China'},
#      {'fsq_id': '5099f5a0e4b00dfcbb15d8f0',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'China Southern Airlines'},
#      {'fsq_id': '526df718498e6e8a38a7c237',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'KAL Prestige Lounge'},
#      {'fsq_id': '4b039d4bf964a520e54f22e3',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'Star Alliance Lounge'},
#      {'fsq_id': '4da4a867b521224bf06437ee',
#       'categories': [{'id': 19070,
#         'name': 'Airport Ticket Counter',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Ticket Counters',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Lufthansa Check-in'},
#      {'fsq_id': '522f8de0498e113f81008a87',
#       'categories': [{'id': 17100,
#         'name': 'Newsstand',
#         'short_name': 'Newsstand',
#         'plural_name': 'Newsstands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#          'suffix': '.png'}}],
#       'name': 'USA Today Travel Zone'},
#      {'fsq_id': '525a0208498ec17e9c43607c',
#       'categories': [{'id': 13025,
#         'name': 'Wine Bar',
#         'short_name': 'Wine Bar',
#         'plural_name': 'Wine Bars',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#          'suffix': '.png'}},
#        {'id': 13347,
#         'name': 'Tapas Restaurant',
#         'short_name': 'Tapas',
#         'plural_name': 'Tapas Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#          'suffix': '.png'}}],
#       'name': 'Vino Volo'},
#      {'fsq_id': '522f841811d2fbcc98151bc4',
#       'categories': [{'id': 13064,
#         'name': 'Pizzeria',
#         'short_name': 'Pizza',
#         'plural_name': 'Pizzerias',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'}}],
#       'name': '800 Degrees Woodfired Kitchen'},
#      {'fsq_id': '4c38e71edfb0e21e5a83afa8',
#       'categories': [{'id': 17089,
#         'name': 'Gift Store',
#         'short_name': 'Gift Store',
#         'plural_name': 'Gift Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#          'suffix': '.png'}}],
#       'name': 'DFS Galleria'},
#      {'fsq_id': '528be73a11d242c8e173fe29',
#       'categories': [{'id': 17033,
#         'name': 'Department Store',
#         'short_name': 'Department Store',
#         'plural_name': 'Department Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#          'suffix': '.png'}}],
#       'name': 'Bliss'},
#      {'fsq_id': '53127e10498eadeec73b9eb8',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Norwegian Airlines'},
#      {'fsq_id': '4cabfa3ad971b1f75fd72ce1',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Eva Airways'},
#      {'fsq_id': '4c5ba8aa94fd0f470fb3c645',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Fiji Airways'},
#      {'fsq_id': '528e7a4011d204ff94a0ff49',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'TSA Passenger Screening'},
#      {'fsq_id': '5a58ea2816fa041f85962732',
#       'categories': [{'id': 17043,
#         'name': 'Clothing Store',
#         'short_name': 'Apparel',
#         'plural_name': 'Clothing Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#          'suffix': '.png'}}],
#       'name': 'Gucci'},
#      {'fsq_id': '4f0e7ba2e4b06654e3f7fa8e',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Cathay Pacific Airways'},
#      {'fsq_id': '522f8daf498e85d35307849d',
#       'categories': [{'id': 17089,
#         'name': 'Gift Store',
#         'short_name': 'Gift Store',
#         'plural_name': 'Gift Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#          'suffix': '.png'}}],
#       'name': 'Bienvenida Flowers and Gifts at TBIT'},
#      {'fsq_id': '4db732c31e7206c23cee3507',
#       'categories': [{'id': 12064,
#         'name': 'Government Building',
#         'short_name': 'Government',
#         'plural_name': 'Government Buildings',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#          'suffix': '.png'}}],
#       'name': 'Global Entry'},
#      {'fsq_id': '5acf93b4088158513c8257ac',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Hong Kong Airlines'},
#      {'fsq_id': '5d0c7088930069002434d96b',
#       'categories': [{'id': 13145,
#         'name': 'Fast Food Restaurant',
#         'short_name': 'Fast Food',
#         'plural_name': 'Fast Food Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#          'suffix': '.png'}}],
#       'name': 'Pret a Manger'},
#      {'fsq_id': '5b08e959471d6e002c25e34b',
#       'categories': [{'id': 13099,
#         'name': 'Chinese Restaurant',
#         'short_name': 'Chinese',
#         'plural_name': 'Chinese Restaurants',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#          'suffix': '.png'}}],
#       'name': "P.F. Chang's China Bistro"},
#      {'fsq_id': '4c6d2ed01585ef3bb45f099e',
#       'categories': [{'id': 11052,
#         'name': 'Currency Exchange',
#         'short_name': 'Currency Exchange',
#         'plural_name': 'Currency Exchanges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#          'suffix': '.png'}}],
#       'name': 'Ice Currency Exchange'},
#      {'fsq_id': '4b773471f964a520a5872ee3',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'The Los Angeles Business Lounge'},
#      {'fsq_id': '4cf26817a41a60fceacc2cc0',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Philippine Airlines'},
#      {'fsq_id': '525f550f11d2eb81d02a76c1',
#       'categories': [{'id': 17100,
#         'name': 'Newsstand',
#         'short_name': 'Newsstand',
#         'plural_name': 'Newsstands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#          'suffix': '.png'}}],
#       'name': 'The Economist'},
#      {'fsq_id': '522f87fd11d29bb3a02f381e',
#       'categories': [{'id': 19056,
#         'name': 'Travel Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Travel Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'DFS Platinum Services Club at LAX'},
#      {'fsq_id': '5821f6a977259239afbbbc9e',
#       'categories': [{'id': 13334,
#         'name': 'Sandwich Spot',
#         'short_name': 'Sandwich Spot',
#         'plural_name': 'Sandwich Spots',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#          'suffix': '.png'}}],
#       'name': 'Earl of Sandwich'},
#      {'fsq_id': '4a879f66f964a520cd0420e3',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'Qantas First Class Lounge'},
#      {'fsq_id': '4df14dc7ae609e69dd90306d',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Turkish Airlines'},
#      {'fsq_id': '50b7d5f6e4b0fd24a3917d56',
#       'categories': [{'id': 19037,
#         'name': 'Airport Terminal',
#         'short_name': 'Terminal',
#         'plural_name': 'Airport Terminals',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#          'suffix': '.png'}}],
#       'name': 'Tom Bradley International Arrivals'},
#      {'fsq_id': '4b55c305f964a520d6ee27e3',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Hawaiian Airlines Check-in'},
#      {'fsq_id': '4dbad231fa8cee72731f8b08',
#       'categories': [{'id': 19004,
#         'name': 'Border Crossing',
#         'short_name': 'Border Crossing',
#         'plural_name': 'Border Crossings',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#          'suffix': '.png'}}],
#       'name': 'US Customs & Border Protection'},
#      {'fsq_id': '5b9ed08a610f04002c230885',
#       'categories': [{'id': 13064,
#         'name': 'Pizzeria',
#         'short_name': 'Pizza',
#         'plural_name': 'Pizzerias',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'}}],
#       'name': 'Wpizza'},
#      {'fsq_id': '5230c39111d2fbb28273085f',
#       'categories': [{'id': 17100,
#         'name': 'Newsstand',
#         'short_name': 'Newsstand',
#         'plural_name': 'Newsstands',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#          'suffix': '.png'}}],
#       'name': 'Crews of California'},
#      {'fsq_id': '58a910429f25833c39c68786',
#       'categories': [{'id': 19035,
#         'name': 'Airport Lounge',
#         'short_name': 'Lounge',
#         'plural_name': 'Airport Lounges',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#          'suffix': '.png'}}],
#       'name': 'Etihad Airways Lounge'},
#      {'fsq_id': '4daf80ca43a1e3d9e6487f17',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'British Airways'},
#      {'fsq_id': '4ba7d7f6f964a5203eb839e3',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'Air New Zealand Check-in'},
#      {'fsq_id': '535210c6498edb86a20ba3a7',
#       'categories': [{'id': 17033,
#         'name': 'Department Store',
#         'short_name': 'Department Store',
#         'plural_name': 'Department Stores',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#          'suffix': '.png'}}],
#       'name': 'Hermès'},
#      {'fsq_id': '4c34c6aa3896e21e1421ec90',
#       'categories': [{'id': 19036,
#         'name': 'Airport Service',
#         'short_name': 'Airport Service',
#         'plural_name': 'Airport Services',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#          'suffix': '.png'}}],
#       'name': 'LATAM Airlines'}]},
#    'timezone': 'America/Los_Angeles'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 34.031276,
#      'longitude': -118.456806},
#     'radius': 50000}}}}

# %%
airport_la_ = []
for venue in airport_la["results"]:
    name = venue["name"]
    location = venue.get("geocodes", {}).get("main", {})
    latitude = location.get("latitude", "N/A")
    longitude = location.get("longitude", "N/A")
    distance = venue.get("distance", "N/A")
    airport_la_.append({"Name": name, "Latitude": latitude, "Longitude": longitude, "Distance": distance})

airport_df_la = pd.DataFrame(airport_la_)

airport_df_la
# Out:
#                                         Name  Latitude   Longitude  Distance
# 0    Los Angeles International Airport (LAX)  33.94352 -118.408420     10798
# 1  Tom Bradley International Terminal (TBIT)  33.94352 -118.408537     10686

# %%
# Creating a map centered around a location of vegan restaurant
m = folium.Map(location=[airport_df_la.iloc[0]['Latitude'], airport_df_la.iloc[0]['Longitude']], zoom_start=12)

for index, row in airport_df_la.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  tooltip=row['Name'], 
                  icon=folium.Icon(color='green')).add_to(m)

company_location = [34.031276, -118.456806]
folium.Marker(company_location, 
              tooltip='hulu',
              icon=folium.Icon(color='red', icon='cloud')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1968ba2556b69848d778b0865347b905 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1968ba2556b69848d778b0865347b905&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1968ba2556b69848d778b0865347b905 = L.map(
#                 &quot;map_1968ba2556b69848d778b0865347b905&quot;,
#                 {
#                     center: [33.94352, -118.40842],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81b3b91e35bab875c0d6fd1322fa8a8b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1968ba2556b69848d778b0865347b905);
#
#
#             var marker_80cadac6e7ff98ccd0fd23bcbfe6ed1e = L.marker(
#                 [33.94352, -118.40842],
#                 {}
#             ).addTo(map_1968ba2556b69848d778b0865347b905);
#
#
#             var icon_99acf39466cc69bddb3a24af3770ca81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_80cadac6e7ff98ccd0fd23bcbfe6ed1e.setIcon(icon_99acf39466cc69bddb3a24af3770ca81);
#
#
#             marker_80cadac6e7ff98ccd0fd23bcbfe6ed1e.bindTooltip(
#                 `&lt;div&gt;
#                      Los Angeles International Airport (LAX)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b4375ba7be750bd818365fcf2c44aebb = L.marker(
#                 [33.94352, -118.408537],
#                 {}
#             ).addTo(map_1968ba2556b69848d778b0865347b905);
#
#
#             var icon_1db562eb89894f5b98b23daf11318a86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4375ba7be750bd818365fcf2c44aebb.setIcon(icon_1db562eb89894f5b98b23daf11318a86);
#
#
#             marker_b4375ba7be750bd818365fcf2c44aebb.bindTooltip(
#                 `&lt;div&gt;
#                      Tom Bradley International Terminal (TBIT)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3de1c6f4fa47eae591120343797841ae = L.marker(
#                 [34.031276, -118.456806],
#                 {}
#             ).addTo(map_1968ba2556b69848d778b0865347b905);
#
#
#             var icon_69a1f590e4c1700760405bd2a2b5dc74 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3de1c6f4fa47eae591120343797841ae.setIcon(icon_69a1f590e4c1700760405bd2a2b5dc74);
#
#
#             marker_3de1c6f4fa47eae591120343797841ae.bindTooltip(
#                 `&lt;div&gt;
#                      hulu
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# checking the location from the closest airport from Los Angeles - USA

latitude = 34.031276
longitude = -118.456806

geolocator = Nominatim(user_agent="airport_finder")
airport_coordinates = (33.9439667, -118.4109258) 
distance = geodesic((latitude, longitude), airport_coordinates).miles
print(f"The closest airport is Tom Bradley International, Los Angeles, which is approximately {distance:.2f} miles away.")
# Out:
# The closest airport is Tom Bradley International, Los Angeles, which is approximately 6.57 miles away.

# %%
"""
While the aiport is closer to the office in Los Angeles, more criteria were met for the office in San Fracisco
Deciding to place the office iin San Francisco, taking Zynga's place!


"""
